# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import namedtuple, deque
import torch.optim as optim
import random
import matplotlib.pyplot as plt
# %matplotlib inline 

"""Uncomment these two lines to get access to Google Drive"""
#from google.colab import drive
#drive.mount('/content/drive')
import os
import time

# %%
# Actor Neural Network
class Actor(nn.Module):
    def __init__(self, state_size, action_size, seed, fc_units=400, fc1_units=300):
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc_units)
        self.fc2 = nn.Linear(fc_units, fc1_units)
        self.fc3 = nn.Linear(fc1_units, action_size)

    def forward(self, state):
        """Build an actor (policy) network that maps states -> actions."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return F.torch.tanh(self.fc3(x))

# Q1-Q2-Critic Neural Network  
  
class Critic(nn.Module):
    def __init__(self, state_size, action_size, seed, fc1_units=400, fc2_units=300):
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)

        # Q1 architecture
        self.l1 = nn.Linear(state_size + action_size, fc1_units)
        self.l2 = nn.Linear(fc1_units, fc2_units)
        self.l3 = nn.Linear(fc2_units, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_size + action_size, fc1_units)
        self.l5 = nn.Linear(fc1_units, fc2_units)
        self.l6 = nn.Linear(fc2_units, 1)

    def forward(self, state, action):
        """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
        xa = torch.cat([state, action], 1)

        x1 = F.relu(self.l1(xa))
        x1 = F.relu(self.l2(x1))
        x1 = self.l3(x1)

        x2 = F.relu(self.l4(xa))
        x2 = F.relu(self.l5(x2))
        x2 = self.l6(x2)

        return x1, x2


class SysModel(nn.Module):
    def __init__(self, state_size, action_size, fc1_units=400, fc2_units=300):
        super(SysModel, self).__init__()
        self.l1 = nn.Linear(state_size + action_size, fc1_units)
        self.l2 = nn.Linear(fc1_units, fc2_units)
        self.l3 = nn.Linear(fc2_units, state_size)


    def forward(self, state, action):
        """Build a system model to predict the next state at a given state."""
        xa = torch.cat([state, action], 1)

        x1 = F.relu(self.l1(xa))
        x1 = F.relu(self.l2(x1))
        x1 = self.l3(x1)

        return x1

# %%
class TD3_FORK:
    def __init__(
        self,name,env,
        load = False,
        gamma = 0.99, #discount factor
        lr_actor = 3e-4,
        lr_critic = 3e-4,
        lr_sysmodel = 3e-4,
        batch_size = 100,
        buffer_capacity = 1000000,
        tau = 0.02,  #target network update factor
        random_seed = np.random.randint(1,10000),
        cuda = True,
        policy_noise=0.2, 
        std_noise = 0.1,
        noise_clip=0.5,
        policy_freq=2 #target network update period
    ):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.env = env
        self.create_actor()
        self.create_critic()
        self.create_sysmodel()
        self.act_opt = optim.Adam(self.actor.parameters(), lr=lr_actor)
        self.crt_opt = optim.Adam(self.critic.parameters(), lr=lr_critic)
        self.sys_opt = optim.Adam(self.sysmodel.parameters(), lr=lr_sysmodel)
        self.set_weights()
        self.replay_memory_buffer = deque(maxlen = buffer_capacity)
        self.replay_memory_bufferd_dis = deque(maxlen = buffer_capacity)
        self.batch_size = batch_size
        self.tau = tau
        self.policy_freq = policy_freq
        self.gamma = gamma
        self.name = name
        self.upper_bound = self.env.action_space.high[0] #action space upper bound
        self.lower_bound = self.env.action_space.low[0]  #action space lower bound
        self.obs_upper_bound = self.env.observation_space.high[0] #state space upper bound
        self.obs_lower_bound = self.env.observation_space.low[0]  #state space lower bound
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.std_noise = std_noise   
 

    

    def create_actor(self):
        params = {
            'state_size':      self.env.observation_space.shape[0],
            'action_size':     self.env.action_space.shape[0],
            'seed':            88
        }
        self.actor = Actor(**params).to(self.device)
        self.actor_target = Actor(**params).to(self.device)

    def create_critic(self):
        params = {
            'state_size':      self.env.observation_space.shape[0],
            'action_size':     self.env.action_space.shape[0],
            'seed':            88
        }
        self.critic = Critic(**params).to(self.device)
        self.critic_target = Critic(**params).to(self.device)

    def create_sysmodel(self):
        params = {
            'state_size':      self.env.observation_space.shape[0],
            'action_size':     self.env.action_space.shape[0]
        }
        self.sysmodel = SysModel(**params).to(self.device)

    def set_weights(self):
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.critic_target.load_state_dict(self.critic.state_dict())

    def load_weight(self):
        self.actor.load_state_dict(torch.load('/content/drive/My Drive/bipedal/weights/hardcore/actor.pth', map_location=self.device))
        self.critic.load_state_dict(torch.load('/content/drive/My Drive/bipedal/weights/hardcore/critic.pth', map_location=self.device))
        self.actor_target.load_state_dict(torch.load('/content/drive/My Drive/bipedal/weights/hardcore/actor_t.pth', map_location=self.device))
        self.critic_target.load_state_dict(torch.load('/content/drive/My Drive/bipedal/weights/hardcore/critic_t.pth', map_location=self.device))
        self.sysmodel.load_state_dict(torch.load('/content/drive/My Drive/bipedal/weights/hardcore/sysmodel.pth', map_location=self.device))

    def add_to_replay_memory(self, transition, buffername):
        #add samples to replay memory
        buffername.append(transition)

    def get_random_sample_from_replay_mem(self, buffername):
        #random samples from replay memory
        random_sample = random.sample(buffername, self.batch_size)
        return random_sample


    def learn_and_update_weights_by_replay(self,training_iterations, weight, totrain):
        """Update policy and value parameters using given batch of experience tuples.
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value
        """
        # print(len(self.replay_memory_buffer))
        if len(self.replay_memory_buffer) < 1e4:
            return 1
        for it in range(training_iterations):
            mini_batch = self.get_random_sample_from_replay_mem(self.replay_memory_buffer)
            state_batch = torch.from_numpy(np.vstack([i[0] for i in mini_batch])).float().to(self.device)
            action_batch = torch.from_numpy(np.vstack([i[1] for i in mini_batch])).float().to(self.device)
            reward_batch = torch.from_numpy(np.vstack([i[2] for i in mini_batch])).float().to(self.device)
            add_reward_batch = torch.from_numpy(np.vstack([i[3] for i in mini_batch])).float().to(self.device)
            next_state_batch = torch.from_numpy(np.vstack([i[4] for i in mini_batch])).float().to(self.device)
            done_list = torch.from_numpy(np.vstack([i[5] for i in mini_batch]).astype(np.uint8)).float().to(self.device)

            # Training and updating Actor & Critic networks.
            
            #Train Critic
            target_actions = self.actor_target(next_state_batch)
            offset_noises = torch.FloatTensor(action_batch.shape).data.normal_(0, self.policy_noise).to(self.device)

            #clip noise
            offset_noises = offset_noises.clamp(-self.noise_clip, self.noise_clip)
            target_actions = (target_actions + offset_noises).clamp(self.lower_bound, self.upper_bound)

            #Compute the target Q value
            Q_targets1, Q_targets2 = self.critic_target(next_state_batch, target_actions)
            Q_targets = torch.min(Q_targets1, Q_targets2)
            Q_targets = reward_batch + self.gamma * Q_targets * (1 - done_list)

            #Compute current Q estimates
            current_Q1, current_Q2 = self.critic(state_batch, action_batch)
            # Compute critic loss
            critic_loss = F.mse_loss(current_Q1, Q_targets.detach()) + F.mse_loss(current_Q2, Q_targets.detach())
            # Optimize the critic
            self.crt_opt.zero_grad()
            critic_loss.backward()
            self.crt_opt.step()

            self.soft_update_target(self.critic, self.critic_target)


            #Train_sysmodel
            predict_next_state = self.sysmodel(state_batch, action_batch) * (1-done_list)
            next_state_batch = next_state_batch * (1 -done_list)
            sysmodel_loss = F.mse_loss(predict_next_state, next_state_batch.detach())
            self.sys_opt.zero_grad()
            sysmodel_loss.backward()
            self.sys_opt.step()
        
            s_flag = 1 if sysmodel_loss.item() < 0.020  else 0

            #Train Actor
            # Delayed policy updates
            if it % self.policy_freq == 0 and totrain == 1:
                actions = self.actor(state_batch)
                actor_loss1,_ = self.critic_target(state_batch, actions)
                actor_loss1 =  actor_loss1.mean()
                actor_loss =  - actor_loss1 

                if s_flag == 1:
                    p_actions = self.actor(state_batch)
                    p_next_state = self.sysmodel(state_batch, p_actions).clamp(self.obs_lower_bound,self.obs_upper_bound)

                    p_actions2 = self.actor(p_next_state.detach()) * self.upper_bound
                    actor_loss2,_ = self.critic_target(p_next_state.detach(), p_actions2)
                    actor_loss2 = actor_loss2.mean() 

                    p_next_state2= self.sysmodel(p_next_state.detach(), p_actions2).clamp(self.obs_lower_bound,self.obs_upper_bound)
                    p_actions3 = self.actor(p_next_state2.detach()) * self.upper_bound
                    actor_loss3,_ = self.critic_target(p_next_state2.detach(), p_actions3)
                    actor_loss3 = actor_loss3.mean() 

                    actor_loss_final =  actor_loss - weight * (actor_loss2) - 0.5 *  weight * actor_loss3
                else:
                    actor_loss_final =  actor_loss

                self.act_opt.zero_grad()
                actor_loss_final.backward()
                self.act_opt.step()

                #Soft update target models
               
                self.soft_update_target(self.actor, self.actor_target)
                
        return sysmodel_loss.item()

    def soft_update_target(self,local_model,target_model):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(self.tau*local_param.data + (1.0-self.tau)*target_param.data)

    def policy(self,state):
        """select action based on ACTOR"""
        state = torch.from_numpy(state).float().unsqueeze(0).to(self.device)
        self.actor.eval()
        with torch.no_grad():
            actions = self.actor(state).cpu().data.numpy()
        self.actor.train()
        # Adding noise to action
        shift_action = np.random.normal(0, self.std_noise, size=self.env.action_space.shape[0])
        sampled_actions = (actions + shift_action)
        # We make sure action is within bounds
        legal_action = np.clip(sampled_actions,self.lower_bound,self.upper_bound)
        return np.squeeze(legal_action)


    def select_action(self,state):
        """select action based on ACTOR"""
        state = torch.from_numpy(state).float().unsqueeze(0).to(self.device)
        with torch.no_grad():
            actions = self.actor_target(state).cpu().data.numpy()
        return np.squeeze(actions)


    def eval_policy(self, env_name, seed, eval_episodes):
        eval_env = env_name
        # eval_env.seed(seed + 100)

        avg_reward = 0.
        for _ in range(eval_episodes):
            state, done = eval_env.reset(), False
            while not done:
                action = self.select_action(np.array(state))
                state, reward, done, _,_ = eval_env.step(action)
                avg_reward += reward
        avg_reward /= eval_episodes

        print("---------------------------------------")
        print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
        print("---------------------------------------")
        return avg_reward

# %%
"""Install Environment"""
"""You may need to restart the kernel to use BipedalWalker."""
# %pip install Box2D
# Out:
# Requirement already satisfied: Box2D in /home/dsi/saadaty/myenv/lib/python3.9/site-packages (2.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""Training the agent"""
# import Box2D
import numpy as np
np.bool = np.bool_
import gym
gym.logger.set_level(40)
max_steps = 3000
falling_down = 0


if __name__ == '__main__':
    env = gym.make('BipedalWalkerHardcore-v3')
    agent = TD3_FORK('Bipedalhardcore', env, batch_size = 100)
    total_episodes = 100000
    start_timestep=0            #time_step to select action based on Actor
    time_start = time.time()        # Init start time
    ep_reward_list = []
    avg_reward_list = []
    total_timesteps = 0
    sys_loss = 0
    numtrainedexp = 0
    save_time = 0
    expcount = 0
    totrain = 0
    max_rewards = -1000
    for ep in range(total_episodes):
        state = env.reset()
        if isinstance(state, tuple):
            state = state[0]
        episodic_reward = 0
        timestep = 0
        temp_replay_buffer = []

        for st in range(max_steps):

            # Select action randomly or according to policy
            if total_timesteps < start_timestep:
                action = env.action_space.sample()
            else:
                action = agent.policy(state)

            # Recieve state and reward from environment.
            next_state, reward, done, info, _ = env.step(action)
            if isinstance(next_state, tuple):
                next_state = next_state[0]
            #change original reward from -100 to -5 and 5*reward for other values
            episodic_reward += reward
            if reward == -100:
                add_reward = -1
                reward = -5
                falling_down += 1
                expcount += 1
            else:
                add_reward = 0
                reward = 5 * reward

            temp_replay_buffer.append((state, action, reward, add_reward, next_state, done))
            
            # End this episode when `done` is True
            if done:
                if add_reward == -1 or episodic_reward < 250:            
                    totrain = 1
                    for temp in temp_replay_buffer: 
                        agent.add_to_replay_memory(temp, agent.replay_memory_buffer)
                elif expcount > 0 and np.random.rand() > 0.5:
                    totrain = 1
                    expcount -= 10
                    for temp in temp_replay_buffer: 
                        agent.add_to_replay_memory(temp, agent.replay_memory_buffer)
                break
            state = next_state
            timestep += 1     
            total_timesteps += 1
        
        ep_reward_list.append(episodic_reward)
        # Mean of last 100 episodes
        avg_reward = np.mean(ep_reward_list[-100:])
        avg_reward_list.append(avg_reward)
        
        if avg_reward > max_rewards:
            max_rewards = avg_reward
            print(f'max reward: {max_rewards}, episode: {ep}')

        if avg_reward > 294:
            # test_reward = agent.eval_policy(env, seed=88, eval_episodes=10)
            # if test_reward > 300:
            #     final_test_reward = agent.eval_policy(env, seed=88, eval_episodes=100)
            #     if final_test_reward > 300:
            '''
            torch.save(agent.actor.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/actor.pth')
            torch.save(agent.critic.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/critic.pth')
            torch.save(agent.actor_target.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/actor_t.pth')
            torch.save(agent.critic_target.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/critic_t.pth')
            torch.save(agent.sysmodel.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/sysmodel.pth')
            '''
            print("===========================")
            print('Task Solved')
            print("===========================")
            break
                    
        s = (int)(time.time() - time_start)

       
        #Training agent only when new experiences are added to the replay buffer
        weight =  1 - np.clip(np.mean(ep_reward_list[-100:])/300, 0, 1)
        if totrain == 1:
            sys_loss = agent.learn_and_update_weights_by_replay(timestep, weight, totrain)
        else: 
            sys_loss = agent.learn_and_update_weights_by_replay(100, weight, totrain)
        totrain = 0

        print('Ep. {}, Timestep {},  Ep.Timesteps {}, Episode Reward: {:.2f}, Moving Avg.Reward: {:.2f}, Time: {:02}:{:02}:{:02} , Falling down: {}, Weight: {}'
                .format(ep, total_timesteps, timestep,
                      episodic_reward, avg_reward, s//3600, s%3600//60, s%60, falling_down, weight)) 
        '''
        if s // 1800 == save_time:           
            
            torch.save(agent.actor.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/actor-time{}.pth'.format(save_time))
            torch.save(agent.critic.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/critic-time{}.pth'.format(save_time))
            torch.save(agent.actor_target.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/actor_t-time{}.pth'.format(save_time))
            torch.save(agent.critic_target.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/critic_t-time{}.pth'.format(save_time))
            torch.save(agent.sysmodel.state_dict(), '/content/drive/My Drive/bipedal/weights/hardcore/sysmodel-time{}.pth'.format(save_time))        
            print("===========================")
            print('Saving Successfully!')
            print("===========================")
            save_time += 1
        '''
      
# Plotting graph
# Episodes versus Avg. Rewards
plt.plot(avg_reward_list)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()
env.close()
print(f'max reward: {max_rewards}, episode: {ep}')
# Out:
# max reward: -94.17215599329916, episode: 0
# Ep. 0, Timestep 80,  Ep.Timesteps 80, Episode Reward: -94.17, Moving Avg.Reward: -94.17, Time: 00:00:00 , Falling down: 1, Weight: 1.0
# max reward: -93.80025008573728, episode: 1
# Ep. 1, Timestep 168,  Ep.Timesteps 88, Episode Reward: -93.43, Moving Avg.Reward: -93.80, Time: 00:00:00 , Falling down: 2, Weight: 1.0
# max reward: -93.66969429007473, episode: 2
# Ep. 2, Timestep 258,  Ep.Timesteps 90, Episode Reward: -93.41, Moving Avg.Reward: -93.67, Time: 00:00:00 , Falling down: 3, Weight: 1.0
# Ep. 3, Timestep 343,  Ep.Timesteps 85, Episode Reward: -93.68, Moving Avg.Reward: -93.67, Time: 00:00:00 , Falling down: 4, Weight: 1.0
# Ep. 4, Timestep 425,  Ep.Timesteps 82, Episode Reward: -95.00, Moving Avg.Reward: -93.94, Time: 00:00:00 , Falling down: 5, Weight: 1.0
# Ep. 5, Timestep 520,  Ep.Timesteps 95, Episode Reward: -93.13, Moving Avg.Reward: -93.80, Time: 00:00:00 , Falling down: 6, Weight: 1.0
# max reward: -93.66401107444457, episode: 6
# Ep. 6, Timestep 622,  Ep.Timesteps 102, Episode Reward: -92.82, Moving Avg.Reward: -93.66, Time: 00:00:01 , Falling down: 7, Weight: 1.0
# max reward: -93.6321615568032, episode: 7
# Ep. 7, Timestep 707,  Ep.Timesteps 85, Episode Reward: -93.41, Moving Avg.Reward: -93.63, Time: 00:00:01 , Falling down: 8, Weight: 1.0
# Ep. 8, Timestep 816,  Ep.Timesteps 109, Episode Reward: -95.18, Moving Avg.Reward: -93.80, Time: 00:00:01 , Falling down: 9, Weight: 1.0
# Ep. 9, Timestep 902,  Ep.Timesteps 86, Episode Reward: -93.70, Moving Avg.Reward: -93.79, Time: 00:00:01 , Falling down: 10, Weight: 1.0
# Ep. 10, Timestep 985,  Ep.Timesteps 83, Episode Reward: -93.63, Moving Avg.Reward: -93.78, Time: 00:00:01 , Falling down: 11, Weight: 1.0
# Ep. 11, Timestep 1089,  Ep.Timesteps 104, Episode Reward: -93.58, Moving Avg.Reward: -93.76, Time: 00:00:02 , Falling down: 12, Weight: 1.0
# Ep. 12, Timestep 1183,  Ep.Timesteps 94, Episode Reward: -92.91, Moving Avg.Reward: -93.70, Time: 00:00:02 , Falling down: 13, Weight: 1.0
# Ep. 13, Timestep 1294,  Ep.Timesteps 111, Episode Reward: -92.85, Moving Avg.Reward: -93.64, Time: 00:00:02 , Falling down: 14, Weight: 1.0
# Ep. 14, Timestep 1383,  Ep.Timesteps 89, Episode Reward: -93.88, Moving Avg.Reward: -93.65, Time: 00:00:02 , Falling down: 15, Weight: 1.0
# Ep. 15, Timestep 1465,  Ep.Timesteps 82, Episode Reward: -93.77, Moving Avg.Reward: -93.66, Time: 00:00:02 , Falling down: 16, Weight: 1.0
# max reward: -93.61449941516557, episode: 16
# Ep. 16, Timestep 1645,  Ep.Timesteps 180, Episode Reward: -92.88, Moving Avg.Reward: -93.61, Time: 00:00:03 , Falling down: 17, Weight: 1.0
# Ep. 17, Timestep 1756,  Ep.Timesteps 111, Episode Reward: -94.97, Moving Avg.Reward: -93.69, Time: 00:00:03 , Falling down: 18, Weight: 1.0
# Ep. 18, Timestep 1842,  Ep.Timesteps 86, Episode Reward: -93.44, Moving Avg.Reward: -93.68, Time: 00:00:03 , Falling down: 19, Weight: 1.0
# Ep. 19, Timestep 1927,  Ep.Timesteps 85, Episode Reward: -93.93, Moving Avg.Reward: -93.69, Time: 00:00:03 , Falling down: 20, Weight: 1.0
# Ep. 20, Timestep 2005,  Ep.Timesteps 78, Episode Reward: -94.01, Moving Avg.Reward: -93.70, Time: 00:00:03 , Falling down: 21, Weight: 1.0
# Ep. 21, Timestep 2109,  Ep.Timesteps 104, Episode Reward: -93.55, Moving Avg.Reward: -93.70, Time: 00:00:03 , Falling down: 22, Weight: 1.0
# Ep. 22, Timestep 2191,  Ep.Timesteps 82, Episode Reward: -93.69, Moving Avg.Reward: -93.70, Time: 00:00:04 , Falling down: 23, Weight: 1.0
# Ep. 23, Timestep 2302,  Ep.Timesteps 111, Episode Reward: -93.06, Moving Avg.Reward: -93.67, Time: 00:00:04 , Falling down: 24, Weight: 1.0
# Ep. 24, Timestep 2392,  Ep.Timesteps 90, Episode Reward: -93.32, Moving Avg.Reward: -93.66, Time: 00:00:04 , Falling down: 25, Weight: 1.0
# Ep. 25, Timestep 2478,  Ep.Timesteps 86, Episode Reward: -93.63, Moving Avg.Reward: -93.66, Time: 00:00:04 , Falling down: 26, Weight: 1.0
# Ep. 26, Timestep 2577,  Ep.Timesteps 99, Episode Reward: -93.32, Moving Avg.Reward: -93.64, Time: 00:00:04 , Falling down: 27, Weight: 1.0
# Ep. 27, Timestep 2677,  Ep.Timesteps 100, Episode Reward: -93.04, Moving Avg.Reward: -93.62, Time: 00:00:05 , Falling down: 28, Weight: 1.0
# Ep. 28, Timestep 2767,  Ep.Timesteps 90, Episode Reward: -95.95, Moving Avg.Reward: -93.70, Time: 00:00:05 , Falling down: 29, Weight: 1.0
# Ep. 29, Timestep 2850,  Ep.Timesteps 83, Episode Reward: -93.47, Moving Avg.Reward: -93.69, Time: 00:00:05 , Falling down: 30, Weight: 1.0
# Ep. 30, Timestep 2926,  Ep.Timesteps 76, Episode Reward: -94.69, Moving Avg.Reward: -93.73, Time: 00:00:05 , Falling down: 31, Weight: 1.0
# Ep. 31, Timestep 3020,  Ep.Timesteps 94, Episode Reward: -93.04, Moving Avg.Reward: -93.71, Time: 00:00:05 , Falling down: 32, Weight: 1.0
# Ep. 32, Timestep 3105,  Ep.Timesteps 85, Episode Reward: -93.13, Moving Avg.Reward: -93.69, Time: 00:00:05 , Falling down: 33, Weight: 1.0
# Ep. 33, Timestep 3218,  Ep.Timesteps 113, Episode Reward: -92.86, Moving Avg.Reward: -93.66, Time: 00:00:05 , Falling down: 34, Weight: 1.0
# Ep. 34, Timestep 3304,  Ep.Timesteps 86, Episode Reward: -93.18, Moving Avg.Reward: -93.65, Time: 00:00:06 , Falling down: 35, Weight: 1.0
# Ep. 35, Timestep 3390,  Ep.Timesteps 86, Episode Reward: -93.25, Moving Avg.Reward: -93.64, Time: 00:00:06 , Falling down: 36, Weight: 1.0
# Ep. 36, Timestep 3482,  Ep.Timesteps 92, Episode Reward: -93.04, Moving Avg.Reward: -93.62, Time: 00:00:06 , Falling down: 37, Weight: 1.0
# max reward: -93.6096371507604, episode: 37
# Ep. 37, Timestep 3583,  Ep.Timesteps 101, Episode Reward: -93.13, Moving Avg.Reward: -93.61, Time: 00:00:06 , Falling down: 38, Weight: 1.0
# Ep. 38, Timestep 3676,  Ep.Timesteps 93, Episode Reward: -95.10, Moving Avg.Reward: -93.65, Time: 00:00:06 , Falling down: 39, Weight: 1.0
# Ep. 39, Timestep 3768,  Ep.Timesteps 92, Episode Reward: -93.32, Moving Avg.Reward: -93.64, Time: 00:00:06 , Falling down: 40, Weight: 1.0
# Ep. 40, Timestep 3881,  Ep.Timesteps 113, Episode Reward: -92.80, Moving Avg.Reward: -93.62, Time: 00:00:06 , Falling down: 41, Weight: 1.0
# Ep. 41, Timestep 3978,  Ep.Timesteps 97, Episode Reward: -93.42, Moving Avg.Reward: -93.61, Time: 00:00:06 , Falling down: 42, Weight: 1.0
# Ep. 42, Timestep 4059,  Ep.Timesteps 81, Episode Reward: -95.58, Moving Avg.Reward: -93.66, Time: 00:00:07 , Falling down: 43, Weight: 1.0
# Ep. 43, Timestep 4139,  Ep.Timesteps 80, Episode Reward: -94.30, Moving Avg.Reward: -93.67, Time: 00:00:07 , Falling down: 44, Weight: 1.0
# Ep. 44, Timestep 4251,  Ep.Timesteps 112, Episode Reward: -95.39, Moving Avg.Reward: -93.71, Time: 00:00:07 , Falling down: 45, Weight: 1.0
# Ep. 45, Timestep 4332,  Ep.Timesteps 81, Episode Reward: -94.26, Moving Avg.Reward: -93.72, Time: 00:00:07 , Falling down: 46, Weight: 1.0
# Ep. 46, Timestep 4441,  Ep.Timesteps 109, Episode Reward: -120.59, Moving Avg.Reward: -94.30, Time: 00:00:07 , Falling down: 47, Weight: 1.0
# Ep. 47, Timestep 4528,  Ep.Timesteps 87, Episode Reward: -93.54, Moving Avg.Reward: -94.28, Time: 00:00:07 , Falling down: 48, Weight: 1.0
# Ep. 48, Timestep 4634,  Ep.Timesteps 106, Episode Reward: -93.28, Moving Avg.Reward: -94.26, Time: 00:00:07 , Falling down: 49, Weight: 1.0
# Ep. 49, Timestep 4726,  Ep.Timesteps 92, Episode Reward: -93.11, Moving Avg.Reward: -94.24, Time: 00:00:08 , Falling down: 50, Weight: 1.0
# Ep. 50, Timestep 4821,  Ep.Timesteps 95, Episode Reward: -93.50, Moving Avg.Reward: -94.22, Time: 00:00:08 , Falling down: 51, Weight: 1.0
# Ep. 51, Timestep 4902,  Ep.Timesteps 81, Episode Reward: -94.69, Moving Avg.Reward: -94.23, Time: 00:00:08 , Falling down: 52, Weight: 1.0
# Ep. 52, Timestep 5022,  Ep.Timesteps 120, Episode Reward: -94.67, Moving Avg.Reward: -94.24, Time: 00:00:08 , Falling down: 53, Weight: 1.0
# Ep. 53, Timestep 5118,  Ep.Timesteps 96, Episode Reward: -93.52, Moving Avg.Reward: -94.23, Time: 00:00:08 , Falling down: 54, Weight: 1.0
# Ep. 54, Timestep 5245,  Ep.Timesteps 127, Episode Reward: -93.00, Moving Avg.Reward: -94.20, Time: 00:00:08 , Falling down: 55, Weight: 1.0
# Ep. 55, Timestep 5372,  Ep.Timesteps 127, Episode Reward: -94.08, Moving Avg.Reward: -94.20, Time: 00:00:08 , Falling down: 56, Weight: 1.0
# Ep. 56, Timestep 5461,  Ep.Timesteps 89, Episode Reward: -93.44, Moving Avg.Reward: -94.19, Time: 00:00:09 , Falling down: 57, Weight: 1.0
# Ep. 57, Timestep 5537,  Ep.Timesteps 76, Episode Reward: -93.82, Moving Avg.Reward: -94.18, Time: 00:00:09 , Falling down: 58, Weight: 1.0
# Ep. 58, Timestep 5628,  Ep.Timesteps 91, Episode Reward: -92.86, Moving Avg.Reward: -94.16, Time: 00:00:09 , Falling down: 59, Weight: 1.0
# Ep. 59, Timestep 5713,  Ep.Timesteps 85, Episode Reward: -93.67, Moving Avg.Reward: -94.15, Time: 00:00:09 , Falling down: 60, Weight: 1.0
# Ep. 60, Timestep 5816,  Ep.Timesteps 103, Episode Reward: -93.32, Moving Avg.Reward: -94.14, Time: 00:00:09 , Falling down: 61, Weight: 1.0
# Ep. 61, Timestep 5927,  Ep.Timesteps 111, Episode Reward: -92.99, Moving Avg.Reward: -94.12, Time: 00:00:09 , Falling down: 62, Weight: 1.0
# Ep. 62, Timestep 6026,  Ep.Timesteps 99, Episode Reward: -93.38, Moving Avg.Reward: -94.11, Time: 00:00:09 , Falling down: 63, Weight: 1.0
# max reward: -93.11802889362642, episode: 63
# Ep. 63, Timestep 9026,  Ep.Timesteps 3000, Episode Reward: -30.76, Moving Avg.Reward: -93.12, Time: 00:00:14 , Falling down: 63, Weight: 1.0
# Ep. 64, Timestep 9114,  Ep.Timesteps 88, Episode Reward: -93.41, Moving Avg.Reward: -93.12, Time: 00:00:14 , Falling down: 64, Weight: 1.0
# max reward: -93.11617134517685, episode: 65
# Ep. 65, Timestep 9221,  Ep.Timesteps 107, Episode Reward: -92.71, Moving Avg.Reward: -93.12, Time: 00:00:14 , Falling down: 65, Weight: 1.0
# Ep. 66, Timestep 9306,  Ep.Timesteps 85, Episode Reward: -94.14, Moving Avg.Reward: -93.13, Time: 00:00:14 , Falling down: 66, Weight: 1.0
# Ep. 67, Timestep 9392,  Ep.Timesteps 86, Episode Reward: -93.61, Moving Avg.Reward: -93.14, Time: 00:00:14 , Falling down: 67, Weight: 1.0
# Ep. 68, Timestep 9475,  Ep.Timesteps 83, Episode Reward: -93.67, Moving Avg.Reward: -93.15, Time: 00:00:14 , Falling down: 68, Weight: 1.0
# Ep. 69, Timestep 9641,  Ep.Timesteps 166, Episode Reward: -96.37, Moving Avg.Reward: -93.19, Time: 00:00:15 , Falling down: 69, Weight: 1.0
# Ep. 70, Timestep 9798,  Ep.Timesteps 157, Episode Reward: -92.50, Moving Avg.Reward: -93.18, Time: 00:00:15 , Falling down: 70, Weight: 1.0
# Ep. 71, Timestep 9967,  Ep.Timesteps 169, Episode Reward: -92.90, Moving Avg.Reward: -93.18, Time: 00:00:15 , Falling down: 71, Weight: 1.0
# Ep. 72, Timestep 10052,  Ep.Timesteps 85, Episode Reward: -93.33, Moving Avg.Reward: -93.18, Time: 00:00:15 , Falling down: 72, Weight: 1.0
# Ep. 73, Timestep 10164,  Ep.Timesteps 112, Episode Reward: -120.73, Moving Avg.Reward: -93.55, Time: 00:00:15 , Falling down: 73, Weight: 1.0
# Ep. 74, Timestep 10254,  Ep.Timesteps 90, Episode Reward: -93.88, Moving Avg.Reward: -93.56, Time: 00:00:15 , Falling down: 74, Weight: 1.0
# Ep. 75, Timestep 10340,  Ep.Timesteps 86, Episode Reward: -93.87, Moving Avg.Reward: -93.56, Time: 00:00:15 , Falling down: 75, Weight: 1.0
# Ep. 76, Timestep 10421,  Ep.Timesteps 81, Episode Reward: -93.90, Moving Avg.Reward: -93.57, Time: 00:00:16 , Falling down: 76, Weight: 1.0
# Ep. 77, Timestep 10519,  Ep.Timesteps 98, Episode Reward: -93.01, Moving Avg.Reward: -93.56, Time: 00:00:16 , Falling down: 77, Weight: 1.0
# Ep. 78, Timestep 10606,  Ep.Timesteps 87, Episode Reward: -93.85, Moving Avg.Reward: -93.56, Time: 00:00:16 , Falling down: 78, Weight: 1.0
# Ep. 79, Timestep 10677,  Ep.Timesteps 71, Episode Reward: -95.95, Moving Avg.Reward: -93.59, Time: 00:00:16 , Falling down: 79, Weight: 1.0
# Ep. 80, Timestep 10771,  Ep.Timesteps 94, Episode Reward: -92.91, Moving Avg.Reward: -93.58, Time: 00:00:16 , Falling down: 80, Weight: 1.0
# Ep. 81, Timestep 10901,  Ep.Timesteps 130, Episode Reward: -92.49, Moving Avg.Reward: -93.57, Time: 00:00:16 , Falling down: 81, Weight: 1.0
# Ep. 82, Timestep 11010,  Ep.Timesteps 109, Episode Reward: -92.87, Moving Avg.Reward: -93.56, Time: 00:00:16 , Falling down: 82, Weight: 1.0
# Ep. 83, Timestep 11102,  Ep.Timesteps 92, Episode Reward: -93.22, Moving Avg.Reward: -93.56, Time: 00:00:17 , Falling down: 83, Weight: 1.0
# Ep. 84, Timestep 11199,  Ep.Timesteps 97, Episode Reward: -92.77, Moving Avg.Reward: -93.55, Time: 00:00:17 , Falling down: 84, Weight: 1.0
# Ep. 85, Timestep 11306,  Ep.Timesteps 107, Episode Reward: -92.98, Moving Avg.Reward: -93.54, Time: 00:00:17 , Falling down: 85, Weight: 1.0
# Ep. 86, Timestep 11395,  Ep.Timesteps 89, Episode Reward: -93.36, Moving Avg.Reward: -93.54, Time: 00:00:17 , Falling down: 86, Weight: 1.0
# Ep. 87, Timestep 11476,  Ep.Timesteps 81, Episode Reward: -94.31, Moving Avg.Reward: -93.55, Time: 00:00:17 , Falling down: 87, Weight: 1.0
# Ep. 88, Timestep 11579,  Ep.Timesteps 103, Episode Reward: -95.67, Moving Avg.Reward: -93.57, Time: 00:00:17 , Falling down: 88, Weight: 1.0
# Ep. 89, Timestep 11671,  Ep.Timesteps 92, Episode Reward: -93.31, Moving Avg.Reward: -93.57, Time: 00:00:17 , Falling down: 89, Weight: 1.0
# Ep. 90, Timestep 11763,  Ep.Timesteps 92, Episode Reward: -93.44, Moving Avg.Reward: -93.57, Time: 00:00:18 , Falling down: 90, Weight: 1.0
# Ep. 91, Timestep 11878,  Ep.Timesteps 115, Episode Reward: -120.21, Moving Avg.Reward: -93.86, Time: 00:00:18 , Falling down: 91, Weight: 1.0
# Ep. 92, Timestep 11960,  Ep.Timesteps 82, Episode Reward: -93.99, Moving Avg.Reward: -93.86, Time: 00:00:18 , Falling down: 92, Weight: 1.0
# Ep. 93, Timestep 12079,  Ep.Timesteps 119, Episode Reward: -92.69, Moving Avg.Reward: -93.85, Time: 00:00:18 , Falling down: 93, Weight: 1.0
# Ep. 94, Timestep 12187,  Ep.Timesteps 108, Episode Reward: -92.89, Moving Avg.Reward: -93.84, Time: 00:00:18 , Falling down: 94, Weight: 1.0
# Ep. 95, Timestep 12292,  Ep.Timesteps 105, Episode Reward: -92.95, Moving Avg.Reward: -93.83, Time: 00:00:18 , Falling down: 95, Weight: 1.0
# Ep. 96, Timestep 12371,  Ep.Timesteps 79, Episode Reward: -94.01, Moving Avg.Reward: -93.83, Time: 00:00:18 , Falling down: 96, Weight: 1.0
# Ep. 97, Timestep 12450,  Ep.Timesteps 79, Episode Reward: -93.89, Moving Avg.Reward: -93.83, Time: 00:00:19 , Falling down: 97, Weight: 1.0
# Ep. 98, Timestep 12546,  Ep.Timesteps 96, Episode Reward: -93.60, Moving Avg.Reward: -93.83, Time: 00:00:19 , Falling down: 98, Weight: 1.0
# Ep. 99, Timestep 12643,  Ep.Timesteps 97, Episode Reward: -93.03, Moving Avg.Reward: -93.82, Time: 00:00:19 , Falling down: 99, Weight: 1.0
# Ep. 100, Timestep 12724,  Ep.Timesteps 81, Episode Reward: -94.39, Moving Avg.Reward: -93.82, Time: 00:00:19 , Falling down: 100, Weight: 1.0
# Ep. 101, Timestep 12829,  Ep.Timesteps 105, Episode Reward: -93.14, Moving Avg.Reward: -93.82, Time: 00:00:19 , Falling down: 101, Weight: 1.0
# Ep. 102, Timestep 12919,  Ep.Timesteps 90, Episode Reward: -93.16, Moving Avg.Reward: -93.82, Time: 00:00:19 , Falling down: 102, Weight: 1.0
# Ep. 103, Timestep 15919,  Ep.Timesteps 3000, Episode Reward: -252.23, Moving Avg.Reward: -95.40, Time: 00:00:24 , Falling down: 102, Weight: 1.0
# Ep. 104, Timestep 18919,  Ep.Timesteps 3000, Episode Reward: -257.84, Moving Avg.Reward: -97.03, Time: 00:00:30 , Falling down: 102, Weight: 1.0
# Ep. 105, Timestep 18965,  Ep.Timesteps 46, Episode Reward: -119.75, Moving Avg.Reward: -97.30, Time: 00:00:31 , Falling down: 103, Weight: 1.0
# Ep. 106, Timestep 19302,  Ep.Timesteps 337, Episode Reward: -121.52, Moving Avg.Reward: -97.58, Time: 00:00:32 , Falling down: 104, Weight: 1.0
# Ep. 107, Timestep 19367,  Ep.Timesteps 65, Episode Reward: -114.69, Moving Avg.Reward: -97.80, Time: 00:00:38 , Falling down: 105, Weight: 1.0
# Ep. 108, Timestep 19471,  Ep.Timesteps 104, Episode Reward: -116.96, Moving Avg.Reward: -98.01, Time: 00:00:40 , Falling down: 106, Weight: 1.0
# Ep. 109, Timestep 22471,  Ep.Timesteps 3000, Episode Reward: -71.23, Moving Avg.Reward: -97.79, Time: 00:00:45 , Falling down: 106, Weight: 1.0
# Ep. 110, Timestep 25471,  Ep.Timesteps 3000, Episode Reward: -72.66, Moving Avg.Reward: -97.58, Time: 00:00:51 , Falling down: 106, Weight: 1.0
# Ep. 111, Timestep 28471,  Ep.Timesteps 3000, Episode Reward: -71.99, Moving Avg.Reward: -97.36, Time: 00:00:56 , Falling down: 106, Weight: 1.0
# Ep. 112, Timestep 31471,  Ep.Timesteps 3000, Episode Reward: -72.29, Moving Avg.Reward: -97.16, Time: 00:01:01 , Falling down: 106, Weight: 1.0
# Ep. 113, Timestep 34471,  Ep.Timesteps 3000, Episode Reward: -71.63, Moving Avg.Reward: -96.95, Time: 00:01:06 , Falling down: 106, Weight: 1.0
# Ep. 114, Timestep 37471,  Ep.Timesteps 3000, Episode Reward: -79.21, Moving Avg.Reward: -96.80, Time: 00:01:12 , Falling down: 106, Weight: 1.0
# Ep. 115, Timestep 40471,  Ep.Timesteps 3000, Episode Reward: -73.96, Moving Avg.Reward: -96.60, Time: 00:01:17 , Falling down: 106, Weight: 1.0
# Ep. 116, Timestep 43471,  Ep.Timesteps 3000, Episode Reward: -72.33, Moving Avg.Reward: -96.40, Time: 00:01:22 , Falling down: 106, Weight: 1.0
# Ep. 117, Timestep 46471,  Ep.Timesteps 3000, Episode Reward: -79.70, Moving Avg.Reward: -96.24, Time: 00:01:27 , Falling down: 106, Weight: 1.0
# Ep. 118, Timestep 49471,  Ep.Timesteps 3000, Episode Reward: -73.42, Moving Avg.Reward: -96.04, Time: 00:01:32 , Falling down: 106, Weight: 1.0
# Ep. 119, Timestep 52471,  Ep.Timesteps 3000, Episode Reward: -72.23, Moving Avg.Reward: -95.83, Time: 00:01:39 , Falling down: 106, Weight: 1.0
# Ep. 120, Timestep 55471,  Ep.Timesteps 3000, Episode Reward: -78.13, Moving Avg.Reward: -95.67, Time: 00:01:45 , Falling down: 106, Weight: 1.0
# Ep. 121, Timestep 58471,  Ep.Timesteps 3000, Episode Reward: -67.99, Moving Avg.Reward: -95.41, Time: 00:01:50 , Falling down: 106, Weight: 1.0
# Ep. 122, Timestep 61471,  Ep.Timesteps 3000, Episode Reward: -72.88, Moving Avg.Reward: -95.20, Time: 00:01:55 , Falling down: 106, Weight: 1.0
# Ep. 123, Timestep 64471,  Ep.Timesteps 3000, Episode Reward: -72.91, Moving Avg.Reward: -95.00, Time: 00:02:00 , Falling down: 106, Weight: 1.0
# Ep. 124, Timestep 67471,  Ep.Timesteps 3000, Episode Reward: -73.21, Moving Avg.Reward: -94.80, Time: 00:02:05 , Falling down: 106, Weight: 1.0
# Ep. 125, Timestep 70471,  Ep.Timesteps 3000, Episode Reward: -72.18, Moving Avg.Reward: -94.59, Time: 00:02:11 , Falling down: 106, Weight: 1.0
# Ep. 126, Timestep 73471,  Ep.Timesteps 3000, Episode Reward: -72.09, Moving Avg.Reward: -94.37, Time: 00:02:17 , Falling down: 106, Weight: 1.0
# Ep. 127, Timestep 76471,  Ep.Timesteps 3000, Episode Reward: -72.51, Moving Avg.Reward: -94.17, Time: 00:02:22 , Falling down: 106, Weight: 1.0
# Ep. 128, Timestep 79471,  Ep.Timesteps 3000, Episode Reward: -72.64, Moving Avg.Reward: -93.93, Time: 00:02:27 , Falling down: 106, Weight: 1.0
# Ep. 129, Timestep 82471,  Ep.Timesteps 3000, Episode Reward: -75.93, Moving Avg.Reward: -93.76, Time: 00:02:32 , Falling down: 106, Weight: 1.0
# Ep. 130, Timestep 85471,  Ep.Timesteps 3000, Episode Reward: -73.82, Moving Avg.Reward: -93.55, Time: 00:02:37 , Falling down: 106, Weight: 1.0
# Ep. 131, Timestep 88471,  Ep.Timesteps 3000, Episode Reward: -80.75, Moving Avg.Reward: -93.43, Time: 00:02:43 , Falling down: 106, Weight: 1.0
# Ep. 132, Timestep 91471,  Ep.Timesteps 3000, Episode Reward: -76.58, Moving Avg.Reward: -93.26, Time: 00:02:49 , Falling down: 106, Weight: 1.0
# max reward: -93.06160801276876, episode: 133
# Ep. 133, Timestep 94471,  Ep.Timesteps 3000, Episode Reward: -72.80, Moving Avg.Reward: -93.06, Time: 00:02:55 , Falling down: 106, Weight: 1.0
# max reward: -92.93306633832856, episode: 134
# Ep. 134, Timestep 97471,  Ep.Timesteps 3000, Episode Reward: -80.33, Moving Avg.Reward: -92.93, Time: 00:03:00 , Falling down: 106, Weight: 1.0
# max reward: -92.7228658303112, episode: 135
# Ep. 135, Timestep 100471,  Ep.Timesteps 3000, Episode Reward: -72.23, Moving Avg.Reward: -92.72, Time: 00:03:06 , Falling down: 106, Weight: 1.0
# max reward: -92.52459249771769, episode: 136
# Ep. 136, Timestep 103471,  Ep.Timesteps 3000, Episode Reward: -73.22, Moving Avg.Reward: -92.52, Time: 00:03:12 , Falling down: 106, Weight: 1.0
# max reward: -92.31978658992513, episode: 137
# Ep. 137, Timestep 106471,  Ep.Timesteps 3000, Episode Reward: -72.65, Moving Avg.Reward: -92.32, Time: 00:03:17 , Falling down: 106, Weight: 1.0
# max reward: -92.10259916008128, episode: 138
# Ep. 138, Timestep 109471,  Ep.Timesteps 3000, Episode Reward: -73.38, Moving Avg.Reward: -92.10, Time: 00:03:22 , Falling down: 106, Weight: 1.0
# max reward: -91.97031623819593, episode: 139
# Ep. 139, Timestep 112471,  Ep.Timesteps 3000, Episode Reward: -80.10, Moving Avg.Reward: -91.97, Time: 00:03:28 , Falling down: 106, Weight: 1.0
# max reward: -91.83207766161091, episode: 140
# Ep. 140, Timestep 115471,  Ep.Timesteps 3000, Episode Reward: -78.97, Moving Avg.Reward: -91.83, Time: 00:03:33 , Falling down: 106, Weight: 1.0
# max reward: -91.64556562703176, episode: 141
# Ep. 141, Timestep 118471,  Ep.Timesteps 3000, Episode Reward: -74.77, Moving Avg.Reward: -91.65, Time: 00:03:38 , Falling down: 106, Weight: 1.0
# max reward: -91.48892754045431, episode: 142
# Ep. 142, Timestep 121471,  Ep.Timesteps 3000, Episode Reward: -79.92, Moving Avg.Reward: -91.49, Time: 00:03:43 , Falling down: 106, Weight: 1.0
# max reward: -91.28048690001957, episode: 143
# Ep. 143, Timestep 124471,  Ep.Timesteps 3000, Episode Reward: -73.46, Moving Avg.Reward: -91.28, Time: 00:03:48 , Falling down: 106, Weight: 1.0
# max reward: -91.06151387096472, episode: 144
# Ep. 144, Timestep 127471,  Ep.Timesteps 3000, Episode Reward: -73.49, Moving Avg.Reward: -91.06, Time: 00:03:54 , Falling down: 106, Weight: 1.0
# max reward: -90.89336464012982, episode: 145
# Ep. 145, Timestep 130471,  Ep.Timesteps 3000, Episode Reward: -77.45, Moving Avg.Reward: -90.89, Time: 00:03:59 , Falling down: 106, Weight: 1.0
# max reward: -90.40900348026372, episode: 146
# Ep. 146, Timestep 133471,  Ep.Timesteps 3000, Episode Reward: -72.15, Moving Avg.Reward: -90.41, Time: 00:04:05 , Falling down: 106, Weight: 1.0
# max reward: -90.20960850063024, episode: 147
# Ep. 147, Timestep 136471,  Ep.Timesteps 3000, Episode Reward: -73.60, Moving Avg.Reward: -90.21, Time: 00:04:12 , Falling down: 106, Weight: 1.0
# max reward: -90.01542120015849, episode: 148
# Ep. 148, Timestep 139471,  Ep.Timesteps 3000, Episode Reward: -73.87, Moving Avg.Reward: -90.02, Time: 00:04:17 , Falling down: 106, Weight: 1.0
# max reward: -89.81565390850157, episode: 149
# Ep. 149, Timestep 142471,  Ep.Timesteps 3000, Episode Reward: -73.14, Moving Avg.Reward: -89.82, Time: 00:04:22 , Falling down: 106, Weight: 1.0
# max reward: -89.60768936202331, episode: 150
# Ep. 150, Timestep 145471,  Ep.Timesteps 3000, Episode Reward: -72.70, Moving Avg.Reward: -89.61, Time: 00:04:27 , Falling down: 106, Weight: 1.0
# max reward: -89.37558622097035, episode: 151
# Ep. 151, Timestep 148471,  Ep.Timesteps 3000, Episode Reward: -71.48, Moving Avg.Reward: -89.38, Time: 00:04:32 , Falling down: 106, Weight: 1.0
# max reward: -89.21054232033272, episode: 152
# Ep. 152, Timestep 151471,  Ep.Timesteps 3000, Episode Reward: -78.17, Moving Avg.Reward: -89.21, Time: 00:04:37 , Falling down: 106, Weight: 1.0
# max reward: -89.04776242540876, episode: 153
# Ep. 153, Timestep 154471,  Ep.Timesteps 3000, Episode Reward: -77.24, Moving Avg.Reward: -89.05, Time: 00:04:44 , Falling down: 106, Weight: 1.0
# max reward: -88.84530075205856, episode: 154
# Ep. 154, Timestep 157471,  Ep.Timesteps 3000, Episode Reward: -72.75, Moving Avg.Reward: -88.85, Time: 00:04:49 , Falling down: 106, Weight: 1.0
# max reward: -88.62843252649833, episode: 155
# Ep. 155, Timestep 160471,  Ep.Timesteps 3000, Episode Reward: -72.40, Moving Avg.Reward: -88.63, Time: 00:04:54 , Falling down: 106, Weight: 1.0
# max reward: -88.41855697422716, episode: 156
# Ep. 156, Timestep 163471,  Ep.Timesteps 3000, Episode Reward: -72.46, Moving Avg.Reward: -88.42, Time: 00:04:59 , Falling down: 106, Weight: 1.0
# max reward: -88.20591240560432, episode: 157
# Ep. 157, Timestep 166471,  Ep.Timesteps 3000, Episode Reward: -72.56, Moving Avg.Reward: -88.21, Time: 00:05:04 , Falling down: 106, Weight: 1.0
# max reward: -88.03813619867591, episode: 158
# Ep. 158, Timestep 169471,  Ep.Timesteps 3000, Episode Reward: -76.08, Moving Avg.Reward: -88.04, Time: 00:05:10 , Falling down: 106, Weight: 1.0
# max reward: -87.82154631556391, episode: 159
# Ep. 159, Timestep 172471,  Ep.Timesteps 3000, Episode Reward: -72.01, Moving Avg.Reward: -87.82, Time: 00:05:15 , Falling down: 106, Weight: 1.0
# max reward: -87.6819353937904, episode: 160
# Ep. 160, Timestep 175471,  Ep.Timesteps 3000, Episode Reward: -79.36, Moving Avg.Reward: -87.68, Time: 00:05:20 , Falling down: 106, Weight: 1.0
# max reward: -87.53895182896855, episode: 161
# Ep. 161, Timestep 178471,  Ep.Timesteps 3000, Episode Reward: -78.69, Moving Avg.Reward: -87.54, Time: 00:05:25 , Falling down: 106, Weight: 1.0
# max reward: -87.33578728946436, episode: 162
# Ep. 162, Timestep 181471,  Ep.Timesteps 3000, Episode Reward: -73.06, Moving Avg.Reward: -87.34, Time: 00:05:30 , Falling down: 106, Weight: 1.0
# Ep. 163, Timestep 184471,  Ep.Timesteps 3000, Episode Reward: -72.62, Moving Avg.Reward: -87.75, Time: 00:05:36 , Falling down: 106, Weight: 1.0
# Ep. 164, Timestep 187471,  Ep.Timesteps 3000, Episode Reward: -73.67, Moving Avg.Reward: -87.56, Time: 00:05:41 , Falling down: 106, Weight: 1.0
# Ep. 165, Timestep 190471,  Ep.Timesteps 3000, Episode Reward: -71.86, Moving Avg.Reward: -87.35, Time: 00:05:46 , Falling down: 106, Weight: 1.0
# max reward: -87.13250703119255, episode: 166
# Ep. 166, Timestep 193471,  Ep.Timesteps 3000, Episode Reward: -72.54, Moving Avg.Reward: -87.13, Time: 00:05:51 , Falling down: 106, Weight: 1.0
# max reward: -86.91851258879834, episode: 167
# Ep. 167, Timestep 196471,  Ep.Timesteps 3000, Episode Reward: -72.21, Moving Avg.Reward: -86.92, Time: 00:05:56 , Falling down: 106, Weight: 1.0
# max reward: -86.76153206441246, episode: 168
# Ep. 168, Timestep 199471,  Ep.Timesteps 3000, Episode Reward: -77.97, Moving Avg.Reward: -86.76, Time: 00:06:01 , Falling down: 106, Weight: 1.0
# max reward: -86.52558984348501, episode: 169
# Ep. 169, Timestep 202471,  Ep.Timesteps 3000, Episode Reward: -72.77, Moving Avg.Reward: -86.53, Time: 00:06:06 , Falling down: 106, Weight: 1.0
# max reward: -86.33173020605847, episode: 170
# Ep. 170, Timestep 205471,  Ep.Timesteps 3000, Episode Reward: -73.12, Moving Avg.Reward: -86.33, Time: 00:06:11 , Falling down: 106, Weight: 1.0
# max reward: -86.20253330908699, episode: 171
# Ep. 171, Timestep 208471,  Ep.Timesteps 3000, Episode Reward: -79.98, Moving Avg.Reward: -86.20, Time: 00:06:17 , Falling down: 106, Weight: 1.0
# max reward: -86.00230568155389, episode: 172
# Ep. 172, Timestep 211471,  Ep.Timesteps 3000, Episode Reward: -73.30, Moving Avg.Reward: -86.00, Time: 00:06:22 , Falling down: 106, Weight: 1.0
# max reward: -85.52363661223366, episode: 173
# Ep. 173, Timestep 214471,  Ep.Timesteps 3000, Episode Reward: -72.86, Moving Avg.Reward: -85.52, Time: 00:06:28 , Falling down: 106, Weight: 1.0
# max reward: -85.30475120387744, episode: 174
# Ep. 174, Timestep 217471,  Ep.Timesteps 3000, Episode Reward: -72.00, Moving Avg.Reward: -85.30, Time: 00:06:33 , Falling down: 106, Weight: 1.0
# max reward: -85.1021511637668, episode: 175
# Ep. 175, Timestep 220471,  Ep.Timesteps 3000, Episode Reward: -73.61, Moving Avg.Reward: -85.10, Time: 00:06:38 , Falling down: 106, Weight: 1.0
# max reward: -84.87522788946991, episode: 176
# Ep. 176, Timestep 223471,  Ep.Timesteps 3000, Episode Reward: -71.21, Moving Avg.Reward: -84.88, Time: 00:06:43 , Falling down: 106, Weight: 1.0
# max reward: -84.6704241966587, episode: 177
# Ep. 177, Timestep 226471,  Ep.Timesteps 3000, Episode Reward: -72.53, Moving Avg.Reward: -84.67, Time: 00:06:49 , Falling down: 106, Weight: 1.0
# max reward: -84.4499614521224, episode: 178
# Ep. 178, Timestep 229471,  Ep.Timesteps 3000, Episode Reward: -71.80, Moving Avg.Reward: -84.45, Time: 00:06:54 , Falling down: 106, Weight: 1.0
# max reward: -84.20706694362062, episode: 179
# Ep. 179, Timestep 232471,  Ep.Timesteps 3000, Episode Reward: -71.66, Moving Avg.Reward: -84.21, Time: 00:06:59 , Falling down: 106, Weight: 1.0
# max reward: -84.06747249166251, episode: 180
# Ep. 180, Timestep 235471,  Ep.Timesteps 3000, Episode Reward: -78.95, Moving Avg.Reward: -84.07, Time: 00:07:04 , Falling down: 106, Weight: 1.0
# max reward: -83.92925097062971, episode: 181
# Ep. 181, Timestep 238471,  Ep.Timesteps 3000, Episode Reward: -78.67, Moving Avg.Reward: -83.93, Time: 00:07:08 , Falling down: 106, Weight: 1.0
# Ep. 182, Timestep 238583,  Ep.Timesteps 112, Episode Reward: -104.56, Moving Avg.Reward: -84.05, Time: 00:07:10 , Falling down: 107, Weight: 1.0
# Ep. 183, Timestep 241583,  Ep.Timesteps 3000, Episode Reward: -177.43, Moving Avg.Reward: -84.89, Time: 00:07:15 , Falling down: 107, Weight: 1.0
# Ep. 184, Timestep 244583,  Ep.Timesteps 3000, Episode Reward: -176.05, Moving Avg.Reward: -85.72, Time: 00:07:20 , Falling down: 107, Weight: 1.0
# Ep. 185, Timestep 247583,  Ep.Timesteps 3000, Episode Reward: -176.42, Moving Avg.Reward: -86.56, Time: 00:07:25 , Falling down: 107, Weight: 1.0
# Ep. 186, Timestep 250583,  Ep.Timesteps 3000, Episode Reward: -176.38, Moving Avg.Reward: -87.39, Time: 00:07:30 , Falling down: 107, Weight: 1.0
# Ep. 187, Timestep 253583,  Ep.Timesteps 3000, Episode Reward: -176.14, Moving Avg.Reward: -88.20, Time: 00:07:35 , Falling down: 107, Weight: 1.0
# Ep. 188, Timestep 253781,  Ep.Timesteps 198, Episode Reward: -109.32, Moving Avg.Reward: -88.34, Time: 00:07:36 , Falling down: 108, Weight: 1.0
# Ep. 189, Timestep 253920,  Ep.Timesteps 139, Episode Reward: -111.28, Moving Avg.Reward: -88.52, Time: 00:07:40 , Falling down: 109, Weight: 1.0
# Ep. 190, Timestep 253965,  Ep.Timesteps 45, Episode Reward: -113.22, Moving Avg.Reward: -88.72, Time: 00:07:42 , Falling down: 110, Weight: 1.0
# Ep. 191, Timestep 254004,  Ep.Timesteps 39, Episode Reward: -110.69, Moving Avg.Reward: -88.62, Time: 00:07:42 , Falling down: 111, Weight: 1.0
# Ep. 192, Timestep 254037,  Ep.Timesteps 33, Episode Reward: -111.76, Moving Avg.Reward: -88.80, Time: 00:07:43 , Falling down: 112, Weight: 1.0
# Ep. 193, Timestep 254089,  Ep.Timesteps 52, Episode Reward: -103.61, Moving Avg.Reward: -88.91, Time: 00:07:44 , Falling down: 113, Weight: 1.0
# Ep. 194, Timestep 254142,  Ep.Timesteps 53, Episode Reward: -100.21, Moving Avg.Reward: -88.98, Time: 00:07:45 , Falling down: 114, Weight: 1.0
# Ep. 195, Timestep 254203,  Ep.Timesteps 61, Episode Reward: -98.95, Moving Avg.Reward: -89.04, Time: 00:07:46 , Falling down: 115, Weight: 1.0
# Ep. 196, Timestep 257203,  Ep.Timesteps 3000, Episode Reward: -146.42, Moving Avg.Reward: -89.57, Time: 00:07:50 , Falling down: 115, Weight: 1.0
# Ep. 197, Timestep 260203,  Ep.Timesteps 3000, Episode Reward: -149.37, Moving Avg.Reward: -90.12, Time: 00:07:56 , Falling down: 115, Weight: 1.0
# Ep. 198, Timestep 260332,  Ep.Timesteps 129, Episode Reward: -102.99, Moving Avg.Reward: -90.22, Time: 00:07:57 , Falling down: 116, Weight: 1.0
# Ep. 199, Timestep 260384,  Ep.Timesteps 52, Episode Reward: -101.83, Moving Avg.Reward: -90.30, Time: 00:07:59 , Falling down: 117, Weight: 1.0
# Ep. 200, Timestep 260460,  Ep.Timesteps 76, Episode Reward: -111.19, Moving Avg.Reward: -90.47, Time: 00:08:00 , Falling down: 118, Weight: 1.0
# Ep. 201, Timestep 260516,  Ep.Timesteps 56, Episode Reward: -99.35, Moving Avg.Reward: -90.53, Time: 00:08:01 , Falling down: 119, Weight: 1.0
# Ep. 202, Timestep 260624,  Ep.Timesteps 108, Episode Reward: -99.40, Moving Avg.Reward: -90.60, Time: 00:08:02 , Falling down: 120, Weight: 1.0
# Ep. 203, Timestep 260694,  Ep.Timesteps 70, Episode Reward: -99.26, Moving Avg.Reward: -89.07, Time: 00:08:04 , Falling down: 121, Weight: 1.0
# Ep. 204, Timestep 260765,  Ep.Timesteps 71, Episode Reward: -98.14, Moving Avg.Reward: -87.47, Time: 00:08:05 , Falling down: 122, Weight: 1.0
# Ep. 205, Timestep 260831,  Ep.Timesteps 66, Episode Reward: -97.06, Moving Avg.Reward: -87.24, Time: 00:08:06 , Falling down: 123, Weight: 1.0
# Ep. 206, Timestep 260922,  Ep.Timesteps 91, Episode Reward: -96.12, Moving Avg.Reward: -86.99, Time: 00:08:07 , Falling down: 124, Weight: 1.0
# Ep. 207, Timestep 260971,  Ep.Timesteps 49, Episode Reward: -101.24, Moving Avg.Reward: -86.85, Time: 00:08:09 , Falling down: 125, Weight: 1.0
# Ep. 208, Timestep 261021,  Ep.Timesteps 50, Episode Reward: -101.72, Moving Avg.Reward: -86.70, Time: 00:08:10 , Falling down: 126, Weight: 1.0
# Ep. 209, Timestep 261110,  Ep.Timesteps 89, Episode Reward: -97.10, Moving Avg.Reward: -86.96, Time: 00:08:11 , Falling down: 127, Weight: 1.0
# Ep. 210, Timestep 261197,  Ep.Timesteps 87, Episode Reward: -118.55, Moving Avg.Reward: -87.42, Time: 00:08:12 , Falling down: 128, Weight: 1.0
# Ep. 211, Timestep 261282,  Ep.Timesteps 85, Episode Reward: -94.97, Moving Avg.Reward: -87.65, Time: 00:08:14 , Falling down: 129, Weight: 1.0
# Ep. 212, Timestep 261345,  Ep.Timesteps 63, Episode Reward: -96.36, Moving Avg.Reward: -87.89, Time: 00:08:15 , Falling down: 130, Weight: 1.0
# Ep. 213, Timestep 261413,  Ep.Timesteps 68, Episode Reward: -95.56, Moving Avg.Reward: -88.13, Time: 00:08:16 , Falling down: 131, Weight: 1.0
# Ep. 214, Timestep 261463,  Ep.Timesteps 50, Episode Reward: -101.43, Moving Avg.Reward: -88.35, Time: 00:08:17 , Falling down: 132, Weight: 1.0
# Ep. 215, Timestep 261517,  Ep.Timesteps 54, Episode Reward: -99.22, Moving Avg.Reward: -88.60, Time: 00:08:18 , Falling down: 133, Weight: 1.0
# Ep. 216, Timestep 261570,  Ep.Timesteps 53, Episode Reward: -98.90, Moving Avg.Reward: -88.87, Time: 00:08:19 , Falling down: 134, Weight: 1.0
# Ep. 217, Timestep 261707,  Ep.Timesteps 137, Episode Reward: -103.09, Moving Avg.Reward: -89.10, Time: 00:08:20 , Falling down: 135, Weight: 1.0
# Ep. 218, Timestep 261856,  Ep.Timesteps 149, Episode Reward: -103.00, Moving Avg.Reward: -89.40, Time: 00:08:23 , Falling down: 136, Weight: 1.0
# Ep. 219, Timestep 261947,  Ep.Timesteps 91, Episode Reward: -103.78, Moving Avg.Reward: -89.71, Time: 00:08:25 , Falling down: 137, Weight: 1.0
# Ep. 220, Timestep 262005,  Ep.Timesteps 58, Episode Reward: -103.39, Moving Avg.Reward: -89.97, Time: 00:08:27 , Falling down: 138, Weight: 1.0
# Ep. 221, Timestep 262109,  Ep.Timesteps 104, Episode Reward: -97.03, Moving Avg.Reward: -90.26, Time: 00:08:28 , Falling down: 139, Weight: 1.0
# Ep. 222, Timestep 262166,  Ep.Timesteps 57, Episode Reward: -99.17, Moving Avg.Reward: -90.52, Time: 00:08:30 , Falling down: 140, Weight: 1.0
# Ep. 223, Timestep 262227,  Ep.Timesteps 61, Episode Reward: -98.14, Moving Avg.Reward: -90.77, Time: 00:08:31 , Falling down: 141, Weight: 1.0
# Ep. 224, Timestep 262287,  Ep.Timesteps 60, Episode Reward: -97.54, Moving Avg.Reward: -91.02, Time: 00:08:31 , Falling down: 142, Weight: 1.0
# Ep. 225, Timestep 262346,  Ep.Timesteps 59, Episode Reward: -98.43, Moving Avg.Reward: -91.28, Time: 00:08:32 , Falling down: 143, Weight: 1.0
# Ep. 226, Timestep 262405,  Ep.Timesteps 59, Episode Reward: -98.21, Moving Avg.Reward: -91.54, Time: 00:08:33 , Falling down: 144, Weight: 1.0
# Ep. 227, Timestep 262467,  Ep.Timesteps 62, Episode Reward: -97.63, Moving Avg.Reward: -91.79, Time: 00:08:34 , Falling down: 145, Weight: 1.0
# Ep. 228, Timestep 262538,  Ep.Timesteps 71, Episode Reward: -97.50, Moving Avg.Reward: -92.04, Time: 00:08:36 , Falling down: 146, Weight: 1.0
# Ep. 229, Timestep 262620,  Ep.Timesteps 82, Episode Reward: -98.72, Moving Avg.Reward: -92.27, Time: 00:08:37 , Falling down: 147, Weight: 1.0
# Ep. 230, Timestep 262681,  Ep.Timesteps 61, Episode Reward: -99.22, Moving Avg.Reward: -92.52, Time: 00:08:38 , Falling down: 148, Weight: 1.0
# Ep. 231, Timestep 262745,  Ep.Timesteps 64, Episode Reward: -96.71, Moving Avg.Reward: -92.68, Time: 00:08:39 , Falling down: 149, Weight: 1.0
# Ep. 232, Timestep 262857,  Ep.Timesteps 112, Episode Reward: -98.65, Moving Avg.Reward: -92.90, Time: 00:08:40 , Falling down: 150, Weight: 1.0
# Ep. 233, Timestep 262916,  Ep.Timesteps 59, Episode Reward: -100.03, Moving Avg.Reward: -93.17, Time: 00:08:42 , Falling down: 151, Weight: 1.0
# Ep. 234, Timestep 262981,  Ep.Timesteps 65, Episode Reward: -97.78, Moving Avg.Reward: -93.35, Time: 00:08:43 , Falling down: 152, Weight: 1.0
# Ep. 235, Timestep 263051,  Ep.Timesteps 70, Episode Reward: -96.24, Moving Avg.Reward: -93.59, Time: 00:08:44 , Falling down: 153, Weight: 1.0
# Ep. 236, Timestep 263125,  Ep.Timesteps 74, Episode Reward: -96.71, Moving Avg.Reward: -93.82, Time: 00:08:45 , Falling down: 154, Weight: 1.0
# Ep. 237, Timestep 263207,  Ep.Timesteps 82, Episode Reward: -98.10, Moving Avg.Reward: -94.08, Time: 00:08:47 , Falling down: 155, Weight: 1.0
# Ep. 238, Timestep 263280,  Ep.Timesteps 73, Episode Reward: -97.59, Moving Avg.Reward: -94.32, Time: 00:08:48 , Falling down: 156, Weight: 1.0
# Ep. 239, Timestep 263352,  Ep.Timesteps 72, Episode Reward: -97.10, Moving Avg.Reward: -94.49, Time: 00:08:49 , Falling down: 157, Weight: 1.0
# Ep. 240, Timestep 263431,  Ep.Timesteps 79, Episode Reward: -95.91, Moving Avg.Reward: -94.66, Time: 00:08:50 , Falling down: 158, Weight: 1.0
# Ep. 241, Timestep 263502,  Ep.Timesteps 71, Episode Reward: -97.30, Moving Avg.Reward: -94.89, Time: 00:08:52 , Falling down: 159, Weight: 1.0
# Ep. 242, Timestep 263577,  Ep.Timesteps 75, Episode Reward: -96.36, Moving Avg.Reward: -95.05, Time: 00:08:53 , Falling down: 160, Weight: 1.0
# Ep. 243, Timestep 263659,  Ep.Timesteps 82, Episode Reward: -98.58, Moving Avg.Reward: -95.30, Time: 00:08:54 , Falling down: 161, Weight: 1.0
# Ep. 244, Timestep 263727,  Ep.Timesteps 68, Episode Reward: -96.63, Moving Avg.Reward: -95.53, Time: 00:08:56 , Falling down: 162, Weight: 1.0
# Ep. 245, Timestep 263798,  Ep.Timesteps 71, Episode Reward: -95.58, Moving Avg.Reward: -95.71, Time: 00:08:57 , Falling down: 163, Weight: 1.0
# Ep. 246, Timestep 263862,  Ep.Timesteps 64, Episode Reward: -96.86, Moving Avg.Reward: -95.96, Time: 00:08:58 , Falling down: 164, Weight: 1.0
# Ep. 247, Timestep 266862,  Ep.Timesteps 3000, Episode Reward: -189.19, Moving Avg.Reward: -97.12, Time: 00:09:03 , Falling down: 164, Weight: 1.0
# Ep. 248, Timestep 266929,  Ep.Timesteps 67, Episode Reward: -96.96, Moving Avg.Reward: -97.35, Time: 00:09:04 , Falling down: 165, Weight: 1.0
# Ep. 249, Timestep 266990,  Ep.Timesteps 61, Episode Reward: -96.57, Moving Avg.Reward: -97.58, Time: 00:09:05 , Falling down: 166, Weight: 1.0
# Ep. 250, Timestep 267062,  Ep.Timesteps 72, Episode Reward: -96.14, Moving Avg.Reward: -97.82, Time: 00:09:06 , Falling down: 167, Weight: 1.0
# Ep. 251, Timestep 267136,  Ep.Timesteps 74, Episode Reward: -95.93, Moving Avg.Reward: -98.06, Time: 00:09:07 , Falling down: 168, Weight: 1.0
# Ep. 252, Timestep 267200,  Ep.Timesteps 64, Episode Reward: -98.42, Moving Avg.Reward: -98.26, Time: 00:09:09 , Falling down: 169, Weight: 1.0
# Ep. 253, Timestep 267270,  Ep.Timesteps 70, Episode Reward: -95.87, Moving Avg.Reward: -98.45, Time: 00:09:10 , Falling down: 170, Weight: 1.0
# Ep. 254, Timestep 267338,  Ep.Timesteps 68, Episode Reward: -95.82, Moving Avg.Reward: -98.68, Time: 00:09:11 , Falling down: 171, Weight: 1.0
# Ep. 255, Timestep 267408,  Ep.Timesteps 70, Episode Reward: -96.16, Moving Avg.Reward: -98.92, Time: 00:09:12 , Falling down: 172, Weight: 1.0
# Ep. 256, Timestep 267484,  Ep.Timesteps 76, Episode Reward: -95.65, Moving Avg.Reward: -99.15, Time: 00:09:13 , Falling down: 173, Weight: 1.0
# Ep. 257, Timestep 267560,  Ep.Timesteps 76, Episode Reward: -95.82, Moving Avg.Reward: -99.38, Time: 00:09:14 , Falling down: 174, Weight: 1.0
# Ep. 258, Timestep 267624,  Ep.Timesteps 64, Episode Reward: -96.21, Moving Avg.Reward: -99.58, Time: 00:09:15 , Falling down: 175, Weight: 1.0
# Ep. 259, Timestep 267682,  Ep.Timesteps 58, Episode Reward: -97.01, Moving Avg.Reward: -99.83, Time: 00:09:16 , Falling down: 176, Weight: 1.0
# Ep. 260, Timestep 267748,  Ep.Timesteps 66, Episode Reward: -96.13, Moving Avg.Reward: -100.00, Time: 00:09:17 , Falling down: 177, Weight: 1.0
# Ep. 261, Timestep 267811,  Ep.Timesteps 63, Episode Reward: -95.96, Moving Avg.Reward: -100.17, Time: 00:09:19 , Falling down: 178, Weight: 1.0
# Ep. 262, Timestep 267886,  Ep.Timesteps 75, Episode Reward: -95.39, Moving Avg.Reward: -100.40, Time: 00:09:20 , Falling down: 179, Weight: 1.0
# Ep. 263, Timestep 267964,  Ep.Timesteps 78, Episode Reward: -94.47, Moving Avg.Reward: -100.62, Time: 00:09:21 , Falling down: 180, Weight: 1.0
# Ep. 264, Timestep 268039,  Ep.Timesteps 75, Episode Reward: -94.51, Moving Avg.Reward: -100.82, Time: 00:09:22 , Falling down: 181, Weight: 1.0
# Ep. 265, Timestep 268112,  Ep.Timesteps 73, Episode Reward: -95.55, Moving Avg.Reward: -101.06, Time: 00:09:23 , Falling down: 182, Weight: 1.0
# Ep. 266, Timestep 268178,  Ep.Timesteps 66, Episode Reward: -96.13, Moving Avg.Reward: -101.30, Time: 00:09:25 , Falling down: 183, Weight: 1.0
# Ep. 267, Timestep 268253,  Ep.Timesteps 75, Episode Reward: -95.23, Moving Avg.Reward: -101.53, Time: 00:09:26 , Falling down: 184, Weight: 1.0
# Ep. 268, Timestep 268317,  Ep.Timesteps 64, Episode Reward: -96.32, Moving Avg.Reward: -101.71, Time: 00:09:27 , Falling down: 185, Weight: 1.0
# Ep. 269, Timestep 268375,  Ep.Timesteps 58, Episode Reward: -97.78, Moving Avg.Reward: -101.96, Time: 00:09:28 , Falling down: 186, Weight: 1.0
# Ep. 270, Timestep 268443,  Ep.Timesteps 68, Episode Reward: -95.88, Moving Avg.Reward: -102.19, Time: 00:09:29 , Falling down: 187, Weight: 1.0
# Ep. 271, Timestep 268508,  Ep.Timesteps 65, Episode Reward: -95.64, Moving Avg.Reward: -102.35, Time: 00:09:30 , Falling down: 188, Weight: 1.0
# Ep. 272, Timestep 268574,  Ep.Timesteps 66, Episode Reward: -96.09, Moving Avg.Reward: -102.57, Time: 00:09:31 , Falling down: 189, Weight: 1.0
# Ep. 273, Timestep 268640,  Ep.Timesteps 66, Episode Reward: -96.87, Moving Avg.Reward: -102.81, Time: 00:09:33 , Falling down: 190, Weight: 1.0
# Ep. 274, Timestep 268699,  Ep.Timesteps 59, Episode Reward: -96.83, Moving Avg.Reward: -103.06, Time: 00:09:34 , Falling down: 191, Weight: 1.0
# Ep. 275, Timestep 268756,  Ep.Timesteps 57, Episode Reward: -97.67, Moving Avg.Reward: -103.30, Time: 00:09:35 , Falling down: 192, Weight: 1.0
# Ep. 276, Timestep 268806,  Ep.Timesteps 50, Episode Reward: -100.60, Moving Avg.Reward: -103.60, Time: 00:09:36 , Falling down: 193, Weight: 1.0
# Ep. 277, Timestep 268871,  Ep.Timesteps 65, Episode Reward: -99.04, Moving Avg.Reward: -103.86, Time: 00:09:37 , Falling down: 194, Weight: 1.0
# Ep. 278, Timestep 268920,  Ep.Timesteps 49, Episode Reward: -99.72, Moving Avg.Reward: -104.14, Time: 00:09:38 , Falling down: 195, Weight: 1.0
# Ep. 279, Timestep 268981,  Ep.Timesteps 61, Episode Reward: -96.82, Moving Avg.Reward: -104.39, Time: 00:09:38 , Falling down: 196, Weight: 1.0
# Ep. 280, Timestep 269033,  Ep.Timesteps 52, Episode Reward: -97.73, Moving Avg.Reward: -104.58, Time: 00:09:39 , Falling down: 197, Weight: 1.0
# Ep. 281, Timestep 269102,  Ep.Timesteps 69, Episode Reward: -95.59, Moving Avg.Reward: -104.75, Time: 00:09:40 , Falling down: 198, Weight: 1.0
# Ep. 282, Timestep 269164,  Ep.Timesteps 62, Episode Reward: -96.18, Moving Avg.Reward: -104.66, Time: 00:09:41 , Falling down: 199, Weight: 1.0
# Ep. 283, Timestep 269246,  Ep.Timesteps 82, Episode Reward: -106.01, Moving Avg.Reward: -103.95, Time: 00:09:42 , Falling down: 200, Weight: 1.0
# Ep. 284, Timestep 269312,  Ep.Timesteps 66, Episode Reward: -95.73, Moving Avg.Reward: -103.15, Time: 00:09:44 , Falling down: 201, Weight: 1.0
# Ep. 285, Timestep 269384,  Ep.Timesteps 72, Episode Reward: -95.27, Moving Avg.Reward: -102.34, Time: 00:09:45 , Falling down: 202, Weight: 1.0
# Ep. 286, Timestep 269453,  Ep.Timesteps 69, Episode Reward: -95.28, Moving Avg.Reward: -101.53, Time: 00:09:46 , Falling down: 203, Weight: 1.0
# Ep. 287, Timestep 269531,  Ep.Timesteps 78, Episode Reward: -95.34, Moving Avg.Reward: -100.72, Time: 00:09:47 , Falling down: 204, Weight: 1.0
# Ep. 288, Timestep 269597,  Ep.Timesteps 66, Episode Reward: -95.37, Moving Avg.Reward: -100.58, Time: 00:09:48 , Falling down: 205, Weight: 1.0
# Ep. 289, Timestep 269662,  Ep.Timesteps 65, Episode Reward: -95.99, Moving Avg.Reward: -100.42, Time: 00:09:50 , Falling down: 206, Weight: 1.0
# Ep. 290, Timestep 269726,  Ep.Timesteps 64, Episode Reward: -95.98, Moving Avg.Reward: -100.25, Time: 00:09:51 , Falling down: 207, Weight: 1.0
# Ep. 291, Timestep 269794,  Ep.Timesteps 68, Episode Reward: -95.10, Moving Avg.Reward: -100.10, Time: 00:09:52 , Falling down: 208, Weight: 1.0
# Ep. 292, Timestep 269868,  Ep.Timesteps 74, Episode Reward: -94.36, Moving Avg.Reward: -99.92, Time: 00:09:53 , Falling down: 209, Weight: 1.0
# Ep. 293, Timestep 269936,  Ep.Timesteps 68, Episode Reward: -95.47, Moving Avg.Reward: -99.84, Time: 00:09:54 , Falling down: 210, Weight: 1.0
# Ep. 294, Timestep 270008,  Ep.Timesteps 72, Episode Reward: -94.82, Moving Avg.Reward: -99.79, Time: 00:09:55 , Falling down: 211, Weight: 1.0
# Ep. 295, Timestep 270083,  Ep.Timesteps 75, Episode Reward: -94.83, Moving Avg.Reward: -99.75, Time: 00:09:57 , Falling down: 212, Weight: 1.0
# Ep. 296, Timestep 270156,  Ep.Timesteps 73, Episode Reward: -94.87, Moving Avg.Reward: -99.23, Time: 00:09:58 , Falling down: 213, Weight: 1.0
# Ep. 297, Timestep 270229,  Ep.Timesteps 73, Episode Reward: -94.85, Moving Avg.Reward: -98.69, Time: 00:09:59 , Falling down: 214, Weight: 1.0
# Ep. 298, Timestep 270294,  Ep.Timesteps 65, Episode Reward: -95.53, Moving Avg.Reward: -98.61, Time: 00:10:00 , Falling down: 215, Weight: 1.0
# Ep. 299, Timestep 270366,  Ep.Timesteps 72, Episode Reward: -95.40, Moving Avg.Reward: -98.55, Time: 00:10:02 , Falling down: 216, Weight: 1.0
# Ep. 300, Timestep 270439,  Ep.Timesteps 73, Episode Reward: -95.08, Moving Avg.Reward: -98.39, Time: 00:10:03 , Falling down: 217, Weight: 1.0
# Ep. 301, Timestep 270508,  Ep.Timesteps 69, Episode Reward: -95.51, Moving Avg.Reward: -98.35, Time: 00:10:04 , Falling down: 218, Weight: 1.0
# Ep. 302, Timestep 270582,  Ep.Timesteps 74, Episode Reward: -94.35, Moving Avg.Reward: -98.30, Time: 00:10:05 , Falling down: 219, Weight: 1.0
# Ep. 303, Timestep 270654,  Ep.Timesteps 72, Episode Reward: -94.83, Moving Avg.Reward: -98.25, Time: 00:10:06 , Falling down: 220, Weight: 1.0
# Ep. 304, Timestep 270730,  Ep.Timesteps 76, Episode Reward: -94.54, Moving Avg.Reward: -98.22, Time: 00:10:08 , Falling down: 221, Weight: 1.0
# Ep. 305, Timestep 270801,  Ep.Timesteps 71, Episode Reward: -95.25, Moving Avg.Reward: -98.20, Time: 00:10:09 , Falling down: 222, Weight: 1.0
# Ep. 306, Timestep 270874,  Ep.Timesteps 73, Episode Reward: -95.48, Moving Avg.Reward: -98.19, Time: 00:10:10 , Falling down: 223, Weight: 1.0
# Ep. 307, Timestep 270949,  Ep.Timesteps 75, Episode Reward: -94.10, Moving Avg.Reward: -98.12, Time: 00:10:11 , Falling down: 224, Weight: 1.0
# Ep. 308, Timestep 271027,  Ep.Timesteps 78, Episode Reward: -94.49, Moving Avg.Reward: -98.05, Time: 00:10:13 , Falling down: 225, Weight: 1.0
# Ep. 309, Timestep 271101,  Ep.Timesteps 74, Episode Reward: -94.37, Moving Avg.Reward: -98.02, Time: 00:10:14 , Falling down: 226, Weight: 1.0
# Ep. 310, Timestep 271180,  Ep.Timesteps 79, Episode Reward: -94.37, Moving Avg.Reward: -97.78, Time: 00:10:15 , Falling down: 227, Weight: 1.0
# Ep. 311, Timestep 271261,  Ep.Timesteps 81, Episode Reward: -93.52, Moving Avg.Reward: -97.76, Time: 00:10:16 , Falling down: 228, Weight: 1.0
# Ep. 312, Timestep 271325,  Ep.Timesteps 64, Episode Reward: -95.44, Moving Avg.Reward: -97.76, Time: 00:10:18 , Falling down: 229, Weight: 1.0
# Ep. 313, Timestep 271395,  Ep.Timesteps 70, Episode Reward: -94.75, Moving Avg.Reward: -97.75, Time: 00:10:19 , Falling down: 230, Weight: 1.0
# Ep. 314, Timestep 271462,  Ep.Timesteps 67, Episode Reward: -94.99, Moving Avg.Reward: -97.68, Time: 00:10:20 , Falling down: 231, Weight: 1.0
# Ep. 315, Timestep 271527,  Ep.Timesteps 65, Episode Reward: -94.94, Moving Avg.Reward: -97.64, Time: 00:10:21 , Falling down: 232, Weight: 1.0
# Ep. 316, Timestep 271603,  Ep.Timesteps 76, Episode Reward: -95.01, Moving Avg.Reward: -97.60, Time: 00:10:22 , Falling down: 233, Weight: 1.0
# Ep. 317, Timestep 271674,  Ep.Timesteps 71, Episode Reward: -95.22, Moving Avg.Reward: -97.52, Time: 00:10:24 , Falling down: 234, Weight: 1.0
# Ep. 318, Timestep 271743,  Ep.Timesteps 69, Episode Reward: -94.99, Moving Avg.Reward: -97.44, Time: 00:10:25 , Falling down: 235, Weight: 1.0
# ...
# Ep. 6762, Timestep 4454083,  Ep.Timesteps 894, Episode Reward: 303.05, Moving Avg.Reward: 282.59, Time: 12:51:05 , Falling down: 3389, Weight: 0.0580430058534146
# Ep. 6763, Timestep 4455014,  Ep.Timesteps 931, Episode Reward: 300.94, Moving Avg.Reward: 282.58, Time: 12:51:09 , Falling down: 3389, Weight: 0.05806219574436666
# Ep. 6764, Timestep 4455872,  Ep.Timesteps 858, Episode Reward: 305.96, Moving Avg.Reward: 282.59, Time: 12:51:12 , Falling down: 3389, Weight: 0.058035751930524015
# Ep. 6765, Timestep 4456781,  Ep.Timesteps 909, Episode Reward: 303.23, Moving Avg.Reward: 282.58, Time: 12:51:16 , Falling down: 3389, Weight: 0.058069574418833536
# Ep. 6766, Timestep 4457684,  Ep.Timesteps 903, Episode Reward: 303.19, Moving Avg.Reward: 282.57, Time: 12:51:20 , Falling down: 3389, Weight: 0.058086466665477565
# Ep. 6767, Timestep 4458585,  Ep.Timesteps 901, Episode Reward: 303.50, Moving Avg.Reward: 286.25, Time: 12:51:23 , Falling down: 3389, Weight: 0.04583202823502097
# Ep. 6768, Timestep 4459498,  Ep.Timesteps 913, Episode Reward: 301.90, Moving Avg.Reward: 286.23, Time: 12:51:27 , Falling down: 3389, Weight: 0.04589043419343286
# Ep. 6769, Timestep 4460436,  Ep.Timesteps 938, Episode Reward: 302.01, Moving Avg.Reward: 286.20, Time: 12:51:31 , Falling down: 3389, Weight: 0.04600042115430025
# max reward: 289.3616744731464, episode: 6770
# Ep. 6770, Timestep 4461356,  Ep.Timesteps 920, Episode Reward: 302.94, Moving Avg.Reward: 289.36, Time: 12:51:34 , Falling down: 3389, Weight: 0.03546108508951196
# max reward: 289.3729345398108, episode: 6771
# Ep. 6771, Timestep 4462272,  Ep.Timesteps 916, Episode Reward: 301.23, Moving Avg.Reward: 289.37, Time: 12:51:38 , Falling down: 3389, Weight: 0.03542355153396404
# Ep. 6772, Timestep 4463163,  Ep.Timesteps 891, Episode Reward: 301.81, Moving Avg.Reward: 289.28, Time: 12:51:42 , Falling down: 3389, Weight: 0.03571905314395585
# Ep. 6773, Timestep 4464096,  Ep.Timesteps 933, Episode Reward: 302.59, Moving Avg.Reward: 289.25, Time: 12:51:46 , Falling down: 3389, Weight: 0.03581848054325476
# Ep. 6774, Timestep 4464974,  Ep.Timesteps 878, Episode Reward: 306.58, Moving Avg.Reward: 289.32, Time: 12:51:49 , Falling down: 3389, Weight: 0.03559771491602681
# Ep. 6775, Timestep 4465855,  Ep.Timesteps 881, Episode Reward: 304.88, Moving Avg.Reward: 289.33, Time: 12:51:53 , Falling down: 3389, Weight: 0.03557633977265162
# Ep. 6776, Timestep 4466753,  Ep.Timesteps 898, Episode Reward: 302.81, Moving Avg.Reward: 289.33, Time: 12:51:56 , Falling down: 3389, Weight: 0.0355781775336419
# Ep. 6777, Timestep 4467673,  Ep.Timesteps 920, Episode Reward: 300.45, Moving Avg.Reward: 289.28, Time: 12:52:00 , Falling down: 3389, Weight: 0.03574740150252431
# Ep. 6778, Timestep 4468601,  Ep.Timesteps 928, Episode Reward: 302.42, Moving Avg.Reward: 289.28, Time: 12:52:03 , Falling down: 3389, Weight: 0.03572580969082384
# Ep. 6779, Timestep 4469546,  Ep.Timesteps 945, Episode Reward: 297.99, Moving Avg.Reward: 289.22, Time: 12:52:07 , Falling down: 3389, Weight: 0.03591923064925939
# Ep. 6780, Timestep 4470499,  Ep.Timesteps 953, Episode Reward: 301.18, Moving Avg.Reward: 289.20, Time: 12:52:10 , Falling down: 3389, Weight: 0.036014988491620326
# Ep. 6781, Timestep 4471445,  Ep.Timesteps 946, Episode Reward: 299.82, Moving Avg.Reward: 289.21, Time: 12:52:14 , Falling down: 3389, Weight: 0.03597541120866865
# Ep. 6782, Timestep 4472318,  Ep.Timesteps 873, Episode Reward: 306.51, Moving Avg.Reward: 289.21, Time: 12:52:17 , Falling down: 3389, Weight: 0.035952014646472685
# Ep. 6783, Timestep 4473223,  Ep.Timesteps 905, Episode Reward: 303.49, Moving Avg.Reward: 289.25, Time: 12:52:21 , Falling down: 3389, Weight: 0.03583212497107546
# Ep. 6784, Timestep 4474211,  Ep.Timesteps 988, Episode Reward: 297.86, Moving Avg.Reward: 289.17, Time: 12:52:24 , Falling down: 3389, Weight: 0.03609160163691383
# Ep. 6785, Timestep 4475147,  Ep.Timesteps 936, Episode Reward: 298.12, Moving Avg.Reward: 289.10, Time: 12:52:28 , Falling down: 3389, Weight: 0.03634204483290582
# Ep. 6786, Timestep 4476068,  Ep.Timesteps 921, Episode Reward: 300.82, Moving Avg.Reward: 289.02, Time: 12:52:31 , Falling down: 3389, Weight: 0.03661019238799401
# Ep. 6787, Timestep 4476983,  Ep.Timesteps 915, Episode Reward: 303.78, Moving Avg.Reward: 288.95, Time: 12:52:35 , Falling down: 3389, Weight: 0.03683728441935652
# Ep. 6788, Timestep 4477924,  Ep.Timesteps 941, Episode Reward: 300.67, Moving Avg.Reward: 288.90, Time: 12:52:38 , Falling down: 3389, Weight: 0.03701297230622591
# Ep. 6789, Timestep 4478835,  Ep.Timesteps 911, Episode Reward: 302.59, Moving Avg.Reward: 288.87, Time: 12:52:42 , Falling down: 3389, Weight: 0.037090722593948744
# Ep. 6790, Timestep 4479769,  Ep.Timesteps 934, Episode Reward: 299.87, Moving Avg.Reward: 288.82, Time: 12:52:45 , Falling down: 3389, Weight: 0.037280962532948214
# Ep. 6791, Timestep 4480657,  Ep.Timesteps 888, Episode Reward: 303.49, Moving Avg.Reward: 288.79, Time: 12:52:49 , Falling down: 3389, Weight: 0.0373539676574417
# Ep. 6792, Timestep 4481562,  Ep.Timesteps 905, Episode Reward: 303.07, Moving Avg.Reward: 288.78, Time: 12:52:53 , Falling down: 3389, Weight: 0.0374107737221302
# Ep. 6793, Timestep 4482513,  Ep.Timesteps 951, Episode Reward: 300.73, Moving Avg.Reward: 288.75, Time: 12:52:56 , Falling down: 3389, Weight: 0.03749826582187721
# Ep. 6794, Timestep 4483422,  Ep.Timesteps 909, Episode Reward: 303.32, Moving Avg.Reward: 288.74, Time: 12:53:00 , Falling down: 3389, Weight: 0.03751723247430472
# Ep. 6795, Timestep 4484018,  Ep.Timesteps 596, Episode Reward: 93.39, Moving Avg.Reward: 286.64, Time: 12:53:03 , Falling down: 3390, Weight: 0.04454668085142055
# Ep. 6796, Timestep 4484971,  Ep.Timesteps 953, Episode Reward: 302.31, Moving Avg.Reward: 286.66, Time: 12:53:21 , Falling down: 3390, Weight: 0.04446943266691983
# Ep. 6797, Timestep 4485601,  Ep.Timesteps 630, Episode Reward: 100.25, Moving Avg.Reward: 284.63, Time: 12:53:24 , Falling down: 3391, Weight: 0.05124613593262095
# Ep. 6798, Timestep 4486482,  Ep.Timesteps 881, Episode Reward: 304.87, Moving Avg.Reward: 284.62, Time: 12:53:42 , Falling down: 3391, Weight: 0.05125643027840754
# Ep. 6799, Timestep 4487536,  Ep.Timesteps 1054, Episode Reward: 293.02, Moving Avg.Reward: 284.55, Time: 12:53:46 , Falling down: 3391, Weight: 0.05150043143901972
# Ep. 6800, Timestep 4488458,  Ep.Timesteps 922, Episode Reward: 302.83, Moving Avg.Reward: 284.53, Time: 12:53:49 , Falling down: 3391, Weight: 0.05156060967270659
# Ep. 6801, Timestep 4489346,  Ep.Timesteps 888, Episode Reward: 307.90, Moving Avg.Reward: 284.55, Time: 12:54:16 , Falling down: 3391, Weight: 0.051493020910145515
# Ep. 6802, Timestep 4490283,  Ep.Timesteps 937, Episode Reward: 303.32, Moving Avg.Reward: 287.42, Time: 12:54:20 , Falling down: 3391, Weight: 0.0419220126104527
# Ep. 6803, Timestep 4491239,  Ep.Timesteps 956, Episode Reward: 300.53, Moving Avg.Reward: 287.37, Time: 12:54:24 , Falling down: 3391, Weight: 0.042101643290719526
# Ep. 6804, Timestep 4492165,  Ep.Timesteps 926, Episode Reward: 303.49, Moving Avg.Reward: 287.31, Time: 12:54:28 , Falling down: 3391, Weight: 0.04231150995847921
# Ep. 6805, Timestep 4493091,  Ep.Timesteps 926, Episode Reward: 301.83, Moving Avg.Reward: 287.24, Time: 12:54:31 , Falling down: 3391, Weight: 0.04251738159082097
# Ep. 6806, Timestep 4494016,  Ep.Timesteps 925, Episode Reward: 303.61, Moving Avg.Reward: 287.26, Time: 12:54:35 , Falling down: 3391, Weight: 0.042477784670632235
# Ep. 6807, Timestep 4494929,  Ep.Timesteps 913, Episode Reward: 306.28, Moving Avg.Reward: 287.27, Time: 12:54:39 , Falling down: 3391, Weight: 0.04244731271918056
# Ep. 6808, Timestep 4495817,  Ep.Timesteps 888, Episode Reward: 308.29, Moving Avg.Reward: 287.27, Time: 12:54:42 , Falling down: 3391, Weight: 0.0424282530234914
# Ep. 6809, Timestep 4496810,  Ep.Timesteps 993, Episode Reward: 299.03, Moving Avg.Reward: 287.17, Time: 12:54:46 , Falling down: 3391, Weight: 0.04277213332307406
# Ep. 6810, Timestep 4497736,  Ep.Timesteps 926, Episode Reward: 306.39, Moving Avg.Reward: 287.17, Time: 12:54:50 , Falling down: 3391, Weight: 0.04275615060026927
# Ep. 6811, Timestep 4498668,  Ep.Timesteps 932, Episode Reward: 303.51, Moving Avg.Reward: 287.22, Time: 12:54:53 , Falling down: 3391, Weight: 0.04260293737206444
# Ep. 6812, Timestep 4499655,  Ep.Timesteps 987, Episode Reward: 297.59, Moving Avg.Reward: 287.13, Time: 12:54:57 , Falling down: 3391, Weight: 0.042907351489331
# Ep. 6813, Timestep 4500537,  Ep.Timesteps 882, Episode Reward: 307.35, Moving Avg.Reward: 287.15, Time: 12:55:01 , Falling down: 3391, Weight: 0.042833583094487704
# Ep. 6814, Timestep 4501414,  Ep.Timesteps 877, Episode Reward: 306.75, Moving Avg.Reward: 287.16, Time: 12:55:04 , Falling down: 3391, Weight: 0.04280716292840814
# Ep. 6815, Timestep 4502347,  Ep.Timesteps 933, Episode Reward: 302.12, Moving Avg.Reward: 287.15, Time: 12:55:08 , Falling down: 3391, Weight: 0.042821171070762554
# Ep. 6816, Timestep 4502538,  Ep.Timesteps 191, Episode Reward: -54.68, Moving Avg.Reward: 283.58, Time: 12:55:10 , Falling down: 3392, Weight: 0.05473789109017502
# Ep. 6817, Timestep 4503464,  Ep.Timesteps 926, Episode Reward: 304.11, Moving Avg.Reward: 283.60, Time: 12:55:17 , Falling down: 3392, Weight: 0.054669348815675534
# Ep. 6818, Timestep 4504423,  Ep.Timesteps 959, Episode Reward: 303.44, Moving Avg.Reward: 283.54, Time: 12:55:21 , Falling down: 3392, Weight: 0.05486035739691997
# Ep. 6819, Timestep 4505450,  Ep.Timesteps 1027, Episode Reward: 297.63, Moving Avg.Reward: 283.42, Time: 12:55:25 , Falling down: 3392, Weight: 0.05528119467239079
# Ep. 6820, Timestep 4506355,  Ep.Timesteps 905, Episode Reward: 303.59, Moving Avg.Reward: 283.36, Time: 12:55:29 , Falling down: 3392, Weight: 0.055458044876438684
# Ep. 6821, Timestep 4507264,  Ep.Timesteps 909, Episode Reward: 308.61, Moving Avg.Reward: 283.37, Time: 12:55:32 , Falling down: 3392, Weight: 0.055418774377060886
# Ep. 6822, Timestep 4508192,  Ep.Timesteps 928, Episode Reward: 305.26, Moving Avg.Reward: 283.41, Time: 12:55:36 , Falling down: 3392, Weight: 0.05530859974523006
# Ep. 6823, Timestep 4509091,  Ep.Timesteps 899, Episode Reward: 306.04, Moving Avg.Reward: 283.45, Time: 12:55:40 , Falling down: 3392, Weight: 0.05517430597006978
# Ep. 6824, Timestep 4510027,  Ep.Timesteps 936, Episode Reward: 302.27, Moving Avg.Reward: 287.11, Time: 12:55:44 , Falling down: 3392, Weight: 0.042958789465687874
# Ep. 6825, Timestep 4510978,  Ep.Timesteps 951, Episode Reward: 302.18, Moving Avg.Reward: 287.09, Time: 12:55:47 , Falling down: 3392, Weight: 0.04304694146753052
# Ep. 6826, Timestep 4511869,  Ep.Timesteps 891, Episode Reward: 308.84, Moving Avg.Reward: 287.10, Time: 12:55:51 , Falling down: 3392, Weight: 0.043000686318853454
# Ep. 6827, Timestep 4512850,  Ep.Timesteps 981, Episode Reward: 301.14, Moving Avg.Reward: 287.05, Time: 12:55:54 , Falling down: 3392, Weight: 0.043178206311975886
# Ep. 6828, Timestep 4513744,  Ep.Timesteps 894, Episode Reward: 307.55, Moving Avg.Reward: 287.05, Time: 12:55:58 , Falling down: 3392, Weight: 0.04317442236356217
# Ep. 6829, Timestep 4514630,  Ep.Timesteps 886, Episode Reward: 307.69, Moving Avg.Reward: 287.06, Time: 12:56:02 , Falling down: 3392, Weight: 0.04314435000227723
# Ep. 6830, Timestep 4515587,  Ep.Timesteps 957, Episode Reward: 300.24, Moving Avg.Reward: 287.00, Time: 12:56:05 , Falling down: 3392, Weight: 0.04333835412535958
# Ep. 6831, Timestep 4516493,  Ep.Timesteps 906, Episode Reward: 305.13, Moving Avg.Reward: 287.02, Time: 12:56:09 , Falling down: 3392, Weight: 0.04325807417557992
# Ep. 6832, Timestep 4517403,  Ep.Timesteps 910, Episode Reward: 304.82, Moving Avg.Reward: 287.00, Time: 12:56:13 , Falling down: 3392, Weight: 0.04332097151745229
# Ep. 6833, Timestep 4518356,  Ep.Timesteps 953, Episode Reward: 303.20, Moving Avg.Reward: 287.05, Time: 12:56:17 , Falling down: 3392, Weight: 0.0431715048324931
# Ep. 6834, Timestep 4519281,  Ep.Timesteps 925, Episode Reward: 303.88, Moving Avg.Reward: 287.05, Time: 12:56:20 , Falling down: 3392, Weight: 0.043162338501009034
# Ep. 6835, Timestep 4520209,  Ep.Timesteps 928, Episode Reward: 305.36, Moving Avg.Reward: 287.05, Time: 12:56:24 , Falling down: 3392, Weight: 0.04316926286734735
# Ep. 6836, Timestep 4521125,  Ep.Timesteps 916, Episode Reward: 307.33, Moving Avg.Reward: 287.04, Time: 12:56:28 , Falling down: 3392, Weight: 0.043216254510265895
# Ep. 6837, Timestep 4522126,  Ep.Timesteps 1001, Episode Reward: 297.84, Moving Avg.Reward: 286.94, Time: 12:56:31 , Falling down: 3392, Weight: 0.043543902137859414
# Ep. 6838, Timestep 4523025,  Ep.Timesteps 899, Episode Reward: 304.16, Moving Avg.Reward: 286.92, Time: 12:56:35 , Falling down: 3392, Weight: 0.043616398710951576
# Ep. 6839, Timestep 4523988,  Ep.Timesteps 963, Episode Reward: 303.68, Moving Avg.Reward: 286.89, Time: 12:56:39 , Falling down: 3392, Weight: 0.04369721331433307
# Ep. 6840, Timestep 4524917,  Ep.Timesteps 929, Episode Reward: 302.68, Moving Avg.Reward: 288.15, Time: 12:56:43 , Falling down: 3392, Weight: 0.03949762415666058
# Ep. 6841, Timestep 4525798,  Ep.Timesteps 881, Episode Reward: 307.48, Moving Avg.Reward: 288.14, Time: 12:56:46 , Falling down: 3392, Weight: 0.039533211180295624
# Ep. 6842, Timestep 4526709,  Ep.Timesteps 911, Episode Reward: 304.42, Moving Avg.Reward: 288.14, Time: 12:56:50 , Falling down: 3392, Weight: 0.039546377101686625
# Ep. 6843, Timestep 4527639,  Ep.Timesteps 930, Episode Reward: 304.11, Moving Avg.Reward: 288.12, Time: 12:56:54 , Falling down: 3392, Weight: 0.03959576265480125
# Ep. 6844, Timestep 4528560,  Ep.Timesteps 921, Episode Reward: 304.31, Moving Avg.Reward: 288.15, Time: 12:56:57 , Falling down: 3392, Weight: 0.03950489675645241
# max reward: 291.3888678219493, episode: 6845
# Ep. 6845, Timestep 4529466,  Ep.Timesteps 906, Episode Reward: 307.49, Moving Avg.Reward: 291.39, Time: 12:57:01 , Falling down: 3392, Weight: 0.028703773926835652
# max reward: 291.40794839361354, episode: 6846
# Ep. 6846, Timestep 4530407,  Ep.Timesteps 941, Episode Reward: 302.92, Moving Avg.Reward: 291.41, Time: 12:57:04 , Falling down: 3392, Weight: 0.028640172021288213
# Ep. 6847, Timestep 4531369,  Ep.Timesteps 962, Episode Reward: 301.29, Moving Avg.Reward: 291.40, Time: 12:57:08 , Falling down: 3392, Weight: 0.028664290266461112
# max reward: 291.48511741605046, episode: 6848
# Ep. 6848, Timestep 4532287,  Ep.Timesteps 918, Episode Reward: 307.20, Moving Avg.Reward: 291.49, Time: 12:57:12 , Falling down: 3392, Weight: 0.028382941946498486
# Ep. 6849, Timestep 4533271,  Ep.Timesteps 984, Episode Reward: 298.49, Moving Avg.Reward: 291.43, Time: 12:57:16 , Falling down: 3392, Weight: 0.028554586192952702
# Ep. 6850, Timestep 4534199,  Ep.Timesteps 928, Episode Reward: 301.50, Moving Avg.Reward: 291.44, Time: 12:57:20 , Falling down: 3392, Weight: 0.028546536985618376
# Ep. 6851, Timestep 4535166,  Ep.Timesteps 967, Episode Reward: 300.40, Moving Avg.Reward: 291.43, Time: 12:57:24 , Falling down: 3392, Weight: 0.028568003083000226
# Ep. 6852, Timestep 4536094,  Ep.Timesteps 928, Episode Reward: 305.11, Moving Avg.Reward: 291.46, Time: 12:57:27 , Falling down: 3392, Weight: 0.028476117741766394
# Ep. 6853, Timestep 4536994,  Ep.Timesteps 900, Episode Reward: 307.32, Moving Avg.Reward: 291.48, Time: 12:57:31 , Falling down: 3392, Weight: 0.028394595051903115
# max reward: 291.51165978341953, episode: 6854
# Ep. 6854, Timestep 4537911,  Ep.Timesteps 917, Episode Reward: 305.37, Moving Avg.Reward: 291.51, Time: 12:57:34 , Falling down: 3392, Weight: 0.02829446738860153
# max reward: 293.4885705376882, episode: 6855
# Ep. 6855, Timestep 4538818,  Ep.Timesteps 907, Episode Reward: 307.54, Moving Avg.Reward: 293.49, Time: 12:57:38 , Falling down: 3392, Weight: 0.021704764874372673
# Ep. 6856, Timestep 4539641,  Ep.Timesteps 823, Episode Reward: 168.71, Moving Avg.Reward: 292.16, Time: 12:57:41 , Falling down: 3393, Weight: 0.02612799414382705
# max reward: 294.2060550524782, episode: 6857
# ===========================
# Task Solved
# ===========================
# max reward: 294.2060550524782, episode: 6857
